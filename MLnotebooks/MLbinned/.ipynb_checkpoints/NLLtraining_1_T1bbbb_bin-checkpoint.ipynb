# %%
import tensorflow as tf
import numpy as np
import pandas as pd
from tensorflow.python.keras.layers import Dense
from tensorflow.python.keras.models import Sequential
from tensorflow.python.keras.losses import binary_crossentropy
import seaborn
from tensorflow.python.keras import optimizers
from tensorflow.python.keras import initializers
import matplotlib.pyplot as plt
from tensorflow.python.keras.callbacks import ModelCheckpoint
import os
from tensorflow.python import keras
import tempfile
import matplotlib as mpl

from sklearn.model_selection import train_test_split

METRICS = [
      keras.metrics.TruePositives(name='tp'),
      keras.metrics.FalsePositives(name='fp'),
      keras.metrics.TrueNegatives(name='tn'),
      keras.metrics.FalseNegatives(name='fn'), 
      keras.metrics.BinaryAccuracy(name='accuracy'),
      keras.metrics.Precision(name='precision'),
      keras.metrics.Recall(name='recall'),
      keras.metrics.AUC(name='auc'),
]

# %%
bkgfiles_2016=[#'/scratch/wjin/featurereduced4/bkg/preselection_2016_qcd_skim.npy',
'/scratch/wjin/featurereduced4/bkg/preselection_2016_singletop_skim.npy',
'/scratch/wjin/featurereduced4/bkg/preselection_2016_tt_skim.npy',
'/scratch/wjin/featurereduced4/bkg/preselection_2016_wjets_skim.npy',
'/scratch/wjin/featurereduced4/bkg/preselection_2016_zinv_skim.npy']

bkgfiles_2017=[#'/scratch/wjin/featurereduced3/bkg/preselection_2017_dyjetsll_slim.npy',
#'/scratch/wjin/featurereduced3/bkg/preselection_2017_gjets_slim.npy',
#'/work/wjin/featurereduced4/bkg/preselection_2017_qcd_skim.npy',
'/scratch/wjin/featurereduced4/bkg/preselection_2017_singletop_skim.npy',
'/scratch/wjin/featurereduced4/bkg/preselection_2017_tt_skim.npy',
#'/scratch/wjin/featurereduced3/bkg/preselection_2017_tt_negligible_slim.npy',
'/scratch/wjin/featurereduced4/bkg/preselection_2017_wjets_skim.npy',
#'/scratch/wjin/featurereduced3/bkg/preselection_2017_ww_wz_slim.npy',
'/scratch/wjin/featurereduced4/bkg/preselection_2017_zinv_skim.npy']

bkgfiles_2018=[#'/scratch/wjin/featurereduced3/bkg/preselection_2018_dyjetsll_slim.npy',
#'/scratch/wjin/featurereduced3/bkg/preselection_2018_gjets_slim.npy',
#'/work/wjin/featurereduced4/bkg/preselection_2018_qcd_skim.npy',
'/scratch/wjin/featurereduced4/bkg/preselection_2018_singletop_skim.npy',
'/scratch/wjin/featurereduced4/bkg/preselection_2018_tt_skim.npy',
#'/scratch/wjin/featurereduced3/bkg/preselection_2018_tt_negligible_slim.npy',
'/scratch/wjin/featurereduced4/bkg/preselection_2018_wjets_skim.npy',
#'/scratch/wjin/featurereduced3/bkg/preselection_2018_ww_wz_slim.npy',
'/scratch/wjin/featurereduced4/bkg/preselection_2018_zinv_skim.npy']

sigfiles_T1bbbb_2016=['/scratch/wjin/featurereduced4/sig/preselection_2016_T1bbbb_94x_1_skim.npy',
                     '/scratch/wjin/featurereduced4/sig/preselection_2016_T1bbbb_94x_2_skim.npy',
                     '/scratch/wjin/featurereduced4/sig/preselection_2016_T1bbbb_94x_skim.npy']

sigfiles_T1bbbb_2017=['/scratch/wjin/featurereduced4/sig/preselection_2017_T1bbbb_1_skim.npy',
                     '/scratch/wjin/featurereduced4/sig/preselection_2017_T1bbbb_2_skim.npy',
                     '/scratch/wjin/featurereduced4/sig/preselection_2017_T1bbbb_ext1_1_skim.npy',
                     '/scratch/wjin/featurereduced4/sig/preselection_2017_T1bbbb_ext1_2_skim.npy',
                     '/scratch/wjin/featurereduced4/sig/preselection_2017_T1bbbb_ext1_3_skim.npy',
                     '/scratch/wjin/featurereduced4/sig/preselection_2017_T1bbbb_ext1_4_skim.npy',
                     '/scratch/wjin/featurereduced4/sig/preselection_2017_T1bbbb_ext1_skim.npy',
                     '/scratch/wjin/featurereduced4/sig/preselection_2017_T1bbbb_skim.npy']

#binning nJet30 nBJet20 ht
htbin=[[250,450],[450,575],[575,1200],[1200,1500],[1500,np.Inf]]
nJet30bin=[[2,4],[4,7],[7,10],[10,16]]
nBJet20bin=[[0,1],[1,2],[2,3],[3,4],[4,16]]
selections=[]
for htrange in range(5):
    selections.append([htbin[htrange],nJet30bin[0],nBJet20bin[0]])
    selections.append([htbin[htrange],nJet30bin[0],nBJet20bin[1]])
    selections.append([htbin[htrange],nJet30bin[0],nBJet20bin[2]])
    selections.append([htbin[htrange],nJet30bin[1],nBJet20bin[0]])
    selections.append([htbin[htrange],nJet30bin[1],nBJet20bin[1]])
    selections.append([htbin[htrange],nJet30bin[1],nBJet20bin[2]])
    selections.append([htbin[htrange],[nJet30bin[0][0],nJet30bin[1][1]],[nBJet20bin[3][0],16]])
for htrange in [0,1]:
    selections.append([htbin[htrange],[nJet30bin[2][0],16],nBJet20bin[0]])
    selections.append([htbin[htrange],[nJet30bin[2][0],16],nBJet20bin[1]])
    selections.append([htbin[htrange],[nJet30bin[2][0],16],nBJet20bin[2]])
    selections.append([htbin[htrange],[nJet30bin[2][0],16],[nBJet20bin[3][0],16]])
for htrange in [2,3,4]:
    selections.append([htbin[htrange],nJet30bin[2],nBJet20bin[0]])
    selections.append([htbin[htrange],nJet30bin[2],nBJet20bin[1]])
    selections.append([htbin[htrange],nJet30bin[2],nBJet20bin[2]])
    selections.append([htbin[htrange],nJet30bin[2],nBJet20bin[3]])
    selections.append([htbin[htrange],nJet30bin[2],nBJet20bin[4]])
    selections.append([htbin[htrange],nJet30bin[3],nBJet20bin[0]])
    selections.append([htbin[htrange],nJet30bin[3],nBJet20bin[1]])
    selections.append([htbin[htrange],nJet30bin[3],nBJet20bin[2]])
    selections.append([htbin[htrange],nJet30bin[3],nBJet20bin[3]])
    selections.append([htbin[htrange],nJet30bin[3],nBJet20bin[4]])

massskim=1
mass1con=1500
mass2con=800

# %%
def significance(data,m1,m2,cut=0.5,weight=b'absweight',sigtag=b'sigtag',score=b'MLscore'):
    b=np.sum(data[(data[sigtag]==0)&(data[score]>cut)][weight])
    if b==0:
        return -1
    q0=0
    s=np.sum(data[(data[sigtag]==1)&(data[b'GenSusyMScan1']==m1)
            &(data[b'GenSusyMScan2']==m2)&(data[score]>cut)][weight])
    if s:
        q0=q0+2*((s+b)*np.log(1+s/b)-s)
    return np.sqrt(q0)

# %%
features_exclude=[b'nJet30',b'nJet40',b'nBJet20',b'nBJet30',b'nBJet40',b'ht',b'mt2',b'mht_pt',b'met_pt',b'mht_phi',b'met_phi',b'njet']
#features_train=[b'deltaPhiMin',b'diffMetMht',
 #         b'jet1_eta',b'jet1_phi',b'jet1_btagDeepCSV',b'jet2_eta',b'jet2_phi',b'jet2_btagDeepCSV',b'jet3_eta',b'jet3_phi',b'jet3_btagDeepCSV',
  #        b'jet4_eta',b'jet4_phi',b'jet4_btagDeepCSV',b'jet5_eta',b'jet5_phi',b'jet5_btagDeepCSV',b'jet6_eta',b'jet6_phi',b'jet6_btagDeepCSV',
   #       b'jet7_eta',b'jet7_phi',b'jet7_btagDeepCSV',b'jet8_eta',b'jet8_phi',b'jet8_btagDeepCSV',b'jet9_eta',b'jet9_phi',b'jet9_btagDeepCSV',
    #      b'jet10_eta',b'jet10_phi',b'jet10_btagDeepCSV',b'jet11_eta',b'jet11_phi',b'jet11_btagDeepCSV',b'jet12_eta',b'jet12_phi',b'jet12_btagDeepCSV',
      #    b'jet13_eta',b'jet13_phi',b'jet13_btagDeepCSV',b'jet14_eta',b'jet14_phi',b'jet14_btagDeepCSV',b'jet15_eta',b'jet15_phi',b'jet15_btagDeepCSV',
       #   b'jet1_pt',b'jet2_pt',b'jet3_pt',b'jet4_pt',b'jet5_pt',
        #  b'jet6_pt',b'jet7_pt',b'jet8_pt',b'jet9_pt',b'jet10_pt',
         # b'jet11_pt',b'jet12_pt',b'jet13_pt',b'jet14_pt',b'jet15_pt']

def feature_choice(njet):
    features_pre=[[b'jet1_eta',b'jet1_phi',b'jet1_pt'],
             [b'jet2_eta',b'jet2_phi',b'jet2_pt'],
             [b'jet3_eta',b'jet3_phi',b'jet3_pt'],
             [b'jet4_eta',b'jet4_phi',b'jet4_pt'],
             [b'jet5_eta',b'jet5_phi',b'jet5_pt'],
             [b'jet6_eta',b'jet6_phi',b'jet6_pt'],
             [b'jet7_eta',b'jet7_phi',b'jet7_pt'],
             [b'jet8_eta',b'jet8_phi',b'jet8_pt'],
             [b'jet9_eta',b'jet9_phi',b'jet9_pt'],
             [b'jet10_eta',b'jet10_phi',b'jet10_pt'],
             [b'jet11_eta',b'jet11_phi',b'jet11_pt'],
             [b'jet12_eta',b'jet12_phi',b'jet12_pt'],
             [b'jet13_eta',b'jet13_phi',b'jet13_pt'],
             [b'jet14_eta',b'jet14_phi',b'jet14_pt'],
             [b'jet15_eta',b'jet15_phi',b'jet15_pt']]
    features_train=[b'deltaPhiMin',b'diffMetMht']
    for i in range(njet):
        features_train=features_train+features_pre[i]
    return features_train

# %%
def plot_history(histories, key_loss='loss'):
    fig=plt.figure(figsize=(16,10))
    ax1 = fig.add_subplot(111)
    for name, history in histories:
        val_loss = ax1.plot(history.epoch, history.history['val_'+key_loss],
                   '--', label=name.title()+' Val - '+key_loss)
        ax1.plot(history.epoch, history.history[key_loss], color=val_loss[0].get_color(),
             label=name.title()+' Train - '+key_loss)
    ax1.set_xlabel('Epochs',fontsize=18)
    ax1.set_ylabel(key_loss+' funtion',fontsize=18)
    ax1.legend(loc='best',prop={'size': 12})
    ax1.set_title('classification learning curve - '+key_loss+' funcion',fontsize=20)
    ax1.set_xlim([0,max(history.epoch)])
    return fig

# %%
databkg_2016=[]
for i in range(4):
    databkg_2016.append(pd.DataFrame(np.load(bkgfiles_2016[i],allow_pickle=True).item()))
    databkg_2016[i][b'bkgtype']=i
databkg_2016=pd.concat(databkg_2016,axis=0)

datasig_T1bbbb_2016=pd.concat([pd.DataFrame(np.load(i,allow_pickle=True).item()) for i in sigfiles_T1bbbb_2016],axis=0)
if massskim:
    datasig_T1bbbb_2016=datasig_T1bbbb_2016[(datasig_T1bbbb_2016[b'GenSusyMScan1']>=mass1con)|(datasig_T1bbbb_2016[b'GenSusyMScan2']>=mass2con)]
datasig_T1bbbb_2016[b'bkgtype']=-1

databkg_2016 = databkg_2016.replace(np.nan, 0)
datasig_T1bbbb_2016= datasig_T1bbbb_2016.replace(np.nan,0)

databkg_2016[b'evt_scale1fb'] = databkg_2016[b'evt_scale1fb'].abs()
databkg_2016[b'absweight'] = databkg_2016[b'absweight'].abs()
datasig_T1bbbb_2016[b'absweight'] = datasig_T1bbbb_2016[b'absweight'].abs()

pd.options.mode.chained_assignment = None
databkg_2016[b'sigtag']=0
datasig_T1bbbb_2016[b'sigtag']=1

# %%
databkg_2016_bin=[]
datasig_T1bbbb_2016_bin=[]
for i in range(len(selections)):
    databkg_2016_bin.append(databkg_2016[(databkg_2016[b'ht']>=selections[i][0][0])
                                              &(databkg_2016[b'ht']<selections[i][0][1])
                                              &(databkg_2016[b'nJet30']>=selections[i][1][0])
                                              &(databkg_2016[b'nJet30']<selections[i][1][1])
                                              &(databkg_2016[b'nBJet20']>=selections[i][2][0])
                                              &(databkg_2016[b'nBJet20']<selections[i][2][1])])
    datasig_T1bbbb_2016_bin.append(datasig_T1bbbb_2016[(datasig_T1bbbb_2016[b'ht']>=selections[i][0][0])
                                              &(datasig_T1bbbb_2016[b'ht']<selections[i][0][1])
                                              &(datasig_T1bbbb_2016[b'nJet30']>=selections[i][1][0])
                                              &(datasig_T1bbbb_2016[b'nJet30']<selections[i][1][1])
                                              &(datasig_T1bbbb_2016[b'nBJet20']>=selections[i][2][0])
                                              &(datasig_T1bbbb_2016[b'nBJet20']<selections[i][2][1])])

# %%
datasig_T1bbbb_2016_ML_bin=[]
databkg_2016_ML_bin=[]
MLuse=[]
for i in range(73):
    if datasig_T1bbbb_2016_bin[i].shape[0]<10000:
        datasig_T1bbbb_2016_ML_bin.append(datasig_T1bbbb_2016_bin[i][datasig_T1bbbb_2016_bin[i][b'MLtag']<20])
        databkg_2016_ML_bin.append(databkg_2016_bin[i][databkg_2016_bin[i][b'MLtag']<20])
        MLuse.append(10)
    elif datasig_T1bbbb_2016_bin[i].shape[0]<20000:
        datasig_T1bbbb_2016_ML_bin.append(datasig_T1bbbb_2016_bin[i][datasig_T1bbbb_2016_bin[i][b'MLtag']<10])
        databkg_2016_ML_bin.append(databkg_2016_bin[i][databkg_2016_bin[i][b'MLtag']<10])
        MLuse.append(5)
    elif datasig_T1bbbb_2016_bin[i].shape[0]<40000:
        datasig_T1bbbb_2016_ML_bin.append(datasig_T1bbbb_2016_bin[i][datasig_T1bbbb_2016_bin[i][b'MLtag']<5])
        databkg_2016_ML_bin.append(databkg_2016_bin[i][databkg_2016_bin[i][b'MLtag']<5])
        MLuse.append(3)
    else:
        datasig_T1bbbb_2016_ML_bin.append(datasig_T1bbbb_2016_bin[i][datasig_T1bbbb_2016_bin[i][b'MLtag']<3])
        databkg_2016_ML_bin.append(databkg_2016_bin[i][databkg_2016_bin[i][b'MLtag']<3])
        MLuse.append(1)

# %%
#data_input=pd.concat([databkg_2016_ML,datasig_T1bbbb_2016_ML],axis=0)
#data_input=data_input.reset_index(drop=True)
#del databkg_2016_ML
#del datasig_T1bbbb_2016_ML
data_input=[]
for i in range(73):
    data_input.append([databkg_2016_ML_bin[i],datasig_T1bbbb_2016_ML_bin[i]])

# %%
i=0
features_train=feature_choice(selections[i][1][1]-1)
data_input[i][0]=data_input[i][0].reset_index(drop=True)
data_input[i][1]=data_input[i][1].reset_index(drop=True)
X=pd.concat(data_input[i],axis=0)[(features_train+[b'evt_scale1fb',b'GenSusyMScan1',b'GenSusyMScan2',b'absweight',b'bkgtype'])[:]]
y=pd.concat(data_input[i],axis=0)[b'sigtag']
X=X.reset_index(drop=True)
y=y.reset_index(drop=True)
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.1, random_state=42)
#train,val=train_test_split(data_input[i][(features_train+[b'evt_scale1fb',b'GenSusyMScan1',b'GenSusyMScan2',b'absweight',b'bkgtype',b'sigtag'])[:]],test_size=0.1, random_state=42)
X_train=X_train.reset_index(drop=True)
y_train=y_train.reset_index(drop=True)
X_val=X_val.reset_index(drop=True)
y_val=y_val.reset_index(drop=True)
#train=train.reset_index(drop=True)
#val=val.reset_index(drop=True)
#y_train=np.array(train.pop(b'sigtag'))
#y_val=np.array(val.pop(b'sigtag'))
#X_train=train[(features_train+[b'evt_scale1fb',b'GenSusyMScan1',b'GenSusyMScan2',b'absweight',b'bkgtype'])[:]]
#X_val=val[(features_train+[b'evt_scale1fb',b'GenSusyMScan1',b'GenSusyMScan2',b'absweight',b'bkgtype'])[:]]
print (y_train[y_train==0].shape[0], y_train[y_train==1].shape[0], y_val[y_val==0].shape[0], y_val[y_val==1].shape[0])
# Out:
# 109903 5614 12233 603

# %%
X0=data_input[i][0][(features_train+[b'evt_scale1fb',b'GenSusyMScan1',b'GenSusyMScan2',b'absweight',b'bkgtype'])[:]]
y0=data_input[i][0][b'sigtag']
X1=data_input[i][1][(features_train+[b'evt_scale1fb',b'GenSusyMScan1',b'GenSusyMScan2',b'absweight',b'bkgtype'])[:]]
y1=data_input[i][1][b'sigtag']
X0_train, X0_val, y0_train, y0_val = train_test_split(X0, y0, test_size=0.1, random_state=42)
X1_train, X1_val, y1_train, y1_val = train_test_split(X1, y1, test_size=0.1, random_state=90)
X0_train=X0_train.reset_index(drop=True)
y0_train=y0_train.reset_index(drop=True)
X0_val=X0_val.reset_index(drop=True)
y0_val=y0_val.reset_index(drop=True)
X1_train=X1_train.reset_index(drop=True)
y1_train=y1_train.reset_index(drop=True)
X1_val=X1_val.reset_index(drop=True)
y1_val=y1_val.reset_index(drop=True)
X_val=pd.concat([X0_val,X1_val])
y_val=pd.concat([y0_val,y1_val])
ids0=np.arange(X0_train.shape[0])
ids1=np.arange(X1_train.shape[0])
#choices = np.random.choice(ids, data_input[i][0].shape[0])
choices0 = np.random.choice(ids0, 200000)
choices1 = np.random.choice(ids1, 200000)
#res_data=pd.concat([data_input[i][1].iloc[choices,:],data_input[i][0]])
res_X_train=pd.concat([X0_train.iloc[choices0,:],X1_train.iloc[choices1,:]])
res_y_train=pd.concat([y0_train.iloc[choices0],y1_train.iloc[choices1]])
res_X_train=res_X_train.reset_index(drop=True)
res_y_train=res_y_train.reset_index(drop=True)
ids0=np.arange(X0_val.shape[0])
ids1=np.arange(X1_val.shape[0])
choices0 = np.random.choice(ids0, 20000)
choices1 = np.random.choice(ids1, 20000)
#res_data=pd.concat([data_input[i][1].iloc[choices,:],data_input[i][0]])
res_X_val=pd.concat([X0_val.iloc[choices0,:],X1_val.iloc[choices1,:]])
res_y_val=pd.concat([y0_val.iloc[choices0],y1_val.iloc[choices1]])
res_X_train=res_X_train.reset_index(drop=True)
res_y_train=res_y_train.reset_index(drop=True)
res_X_val=res_X_val.reset_index(drop=True)
res_y_val=res_y_val.reset_index(drop=True)
print (res_y_train[res_y_train==0].shape[0], res_y_train[res_y_train==1].shape[0], res_y_val[res_y_val==0].shape[0], res_y_val[res_y_val==1].shape[0])
# Out:
# 200000 200000 20000 20000

# %%
def make_model(metrics = METRICS, output_bias=None):
    if output_bias is not None:
        output_bias = tf.keras.initializers.Constant(output_bias)
    model = keras.Sequential([
        keras.layers.Dense(
          30, kernel_initializer='normal', activation='sigmoid',
          input_shape=(len(features_train),)),
        keras.layers.Dropout(0.5),
        keras.layers.Dense(
        10, kernel_initializer='normal', activation='sigmoid'),
        keras.layers.Dense(
        10, kernel_initializer='normal', activation='sigmoid'),
      keras.layers.Dense(1, activation='sigmoid',
                         bias_initializer=output_bias),
  ])
    adam=optimizers.Adam(lr=0.001)
    model.compile(
      optimizer='Adam',
      loss='binary_crossentropy',
      metrics=metrics)

    return model

# %%
early_stopping = tf.keras.callbacks.EarlyStopping(
#    monitor='val_auc', 
    monitor='val_accuracy',
    verbose=1,
    patience=200,
    mode='max',
    restore_best_weights=True)

# %%
def plot_metrics(history):
    metrics =  ['loss', 'auc', 'tp', 'accuracy']
    mpl.rcParams['figure.figsize'] = (12, 10)
    colors = plt.rcParams['axes.prop_cycle'].by_key()['color']
    for n, metric in enumerate(metrics):
        name = metric.replace("_"," ").capitalize()
        plt.subplot(2,2,n+1)
        plt.plot(history.epoch,  history.history[metric], color=colors[0], label='Train')
        plt.plot(history.epoch, history.history['val_'+metric],
             color=colors[0], linestyle="--", label='Val')
        plt.xlabel('Epoch')
        plt.ylabel(name)
        if metric == 'loss':
            plt.ylim([0, plt.ylim()[1]])
        elif metric == 'auc':
            plt.ylim([0,1])
#        else:
#            plt.ylim([0,1])

    plt.legend()

# %%
model = make_model()
#model.load_weights(initial_weights)
baseline_history = model.fit(
    x=res_X_train[features_train[:]],
    y=res_y_train,
    batch_size=10000,
    epochs=200,
    callbacks = [early_stopping],
    validation_data=(res_X_val[features_train[:]], res_y_val))
# Out:
# WARNING:tensorflow:Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>
# Train on 400000 samples, validate on 40000 samples
# Epoch 1/200
# 400000/400000 [==============================] - 2s 5us/sample - loss: 0.6927 - tp: 87135.0000 - fp: 73550.0000 - tn: 126450.0000 - fn: 112865.0000 - accuracy: 0.5340 - precision: 0.5423 - recall: 0.4357 - auc: 0.5313 - val_loss: 0.6915 - val_tp: 7657.0000 - val_fp: 4781.0000 - val_tn: 15219.0000 - val_fn: 12343.0000 - val_accuracy: 0.5719 - val_precision: 0.6156 - val_recall: 0.3828 - val_auc: 0.6047
# Epoch 2/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6880 - tp: 110618.0000 - fp: 79206.0000 - tn: 120794.0000 - fn: 89382.0000 - accuracy: 0.5785 - precision: 0.5827 - recall: 0.5531 - auc: 0.5978 - val_loss: 0.6817 - val_tp: 11627.0000 - val_fp: 8394.0000 - val_tn: 11606.0000 - val_fn: 8373.0000 - val_accuracy: 0.5808 - val_precision: 0.5807 - val_recall: 0.5814 - val_auc: 0.6219
# Epoch 3/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6782 - tp: 122206.0000 - fp: 88165.0000 - tn: 111835.0000 - fn: 77794.0000 - accuracy: 0.5851 - precision: 0.5809 - recall: 0.6110 - auc: 0.6081 - val_loss: 0.6715 - val_tp: 12709.0000 - val_fp: 9174.0000 - val_tn: 10826.0000 - val_fn: 7291.0000 - val_accuracy: 0.5884 - val_precision: 0.5808 - val_recall: 0.6355 - val_auc: 0.6253
# Epoch 4/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6731 - tp: 126220.0000 - fp: 91637.0000 - tn: 108363.0000 - fn: 73780.0000 - accuracy: 0.5865 - precision: 0.5794 - recall: 0.6311 - auc: 0.6146 - val_loss: 0.6681 - val_tp: 13393.0000 - val_fp: 10012.0000 - val_tn: 9988.0000 - val_fn: 6607.0000 - val_accuracy: 0.5845 - val_precision: 0.5722 - val_recall: 0.6697 - val_auc: 0.6263
# Epoch 5/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6715 - tp: 125922.0000 - fp: 91310.0000 - tn: 108690.0000 - fn: 74078.0000 - accuracy: 0.5865 - precision: 0.5797 - recall: 0.6296 - auc: 0.6172 - val_loss: 0.6677 - val_tp: 12612.0000 - val_fp: 8925.0000 - val_tn: 11075.0000 - val_fn: 7388.0000 - val_accuracy: 0.5922 - val_precision: 0.5856 - val_recall: 0.6306 - val_auc: 0.6264
# Epoch 6/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6709 - tp: 124876.0000 - fp: 90257.0000 - tn: 109743.0000 - fn: 75124.0000 - accuracy: 0.5865 - precision: 0.5805 - recall: 0.6244 - auc: 0.6186 - val_loss: 0.6675 - val_tp: 12452.0000 - val_fp: 8709.0000 - val_tn: 11291.0000 - val_fn: 7548.0000 - val_accuracy: 0.5936 - val_precision: 0.5884 - val_recall: 0.6226 - val_auc: 0.6268
# Epoch 7/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6705 - tp: 123485.0000 - fp: 89233.0000 - tn: 110767.0000 - fn: 76515.0000 - accuracy: 0.5856 - precision: 0.5805 - recall: 0.6174 - auc: 0.6194 - val_loss: 0.6673 - val_tp: 12749.0000 - val_fp: 9153.0000 - val_tn: 10847.0000 - val_fn: 7251.0000 - val_accuracy: 0.5899 - val_precision: 0.5821 - val_recall: 0.6374 - val_auc: 0.6267
# Epoch 8/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6702 - tp: 125483.0000 - fp: 90752.0000 - tn: 109248.0000 - fn: 74517.0000 - accuracy: 0.5868 - precision: 0.5803 - recall: 0.6274 - auc: 0.6203 - val_loss: 0.6674 - val_tp: 12854.0000 - val_fp: 9243.0000 - val_tn: 10757.0000 - val_fn: 7146.0000 - val_accuracy: 0.5903 - val_precision: 0.5817 - val_recall: 0.6427 - val_auc: 0.6261
# Epoch 9/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6699 - tp: 126216.0000 - fp: 91543.0000 - tn: 108457.0000 - fn: 73784.0000 - accuracy: 0.5867 - precision: 0.5796 - recall: 0.6311 - auc: 0.6208 - val_loss: 0.6673 - val_tp: 13288.0000 - val_fp: 9906.0000 - val_tn: 10094.0000 - val_fn: 6712.0000 - val_accuracy: 0.5846 - val_precision: 0.5729 - val_recall: 0.6644 - val_auc: 0.6257
# Epoch 10/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6697 - tp: 127534.0000 - fp: 92465.0000 - tn: 107535.0000 - fn: 72466.0000 - accuracy: 0.5877 - precision: 0.5797 - recall: 0.6377 - auc: 0.6217 - val_loss: 0.6673 - val_tp: 12883.0000 - val_fp: 9276.0000 - val_tn: 10724.0000 - val_fn: 7117.0000 - val_accuracy: 0.5902 - val_precision: 0.5814 - val_recall: 0.6442 - val_auc: 0.6262
# Epoch 11/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6695 - tp: 128312.0000 - fp: 92958.0000 - tn: 107042.0000 - fn: 71688.0000 - accuracy: 0.5884 - precision: 0.5799 - recall: 0.6416 - auc: 0.6219 - val_loss: 0.6671 - val_tp: 13164.0000 - val_fp: 9600.0000 - val_tn: 10400.0000 - val_fn: 6836.0000 - val_accuracy: 0.5891 - val_precision: 0.5783 - val_recall: 0.6582 - val_auc: 0.6272
# Epoch 12/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6691 - tp: 130595.0000 - fp: 95217.0000 - tn: 104783.0000 - fn: 69405.0000 - accuracy: 0.5884 - precision: 0.5783 - recall: 0.6530 - auc: 0.6230 - val_loss: 0.6671 - val_tp: 13385.0000 - val_fp: 9942.0000 - val_tn: 10058.0000 - val_fn: 6615.0000 - val_accuracy: 0.5861 - val_precision: 0.5738 - val_recall: 0.6693 - val_auc: 0.6264
# Epoch 13/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6693 - tp: 130652.0000 - fp: 95288.0000 - tn: 104712.0000 - fn: 69348.0000 - accuracy: 0.5884 - precision: 0.5783 - recall: 0.6533 - auc: 0.6228 - val_loss: 0.6671 - val_tp: 13559.0000 - val_fp: 10099.0000 - val_tn: 9901.0000 - val_fn: 6441.0000 - val_accuracy: 0.5865 - val_precision: 0.5731 - val_recall: 0.6780 - val_auc: 0.6259
# Epoch 14/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6692 - tp: 132310.0000 - fp: 96529.0000 - tn: 103471.0000 - fn: 67690.0000 - accuracy: 0.5895 - precision: 0.5782 - recall: 0.6615 - auc: 0.6228 - val_loss: 0.6670 - val_tp: 13337.0000 - val_fp: 9736.0000 - val_tn: 10264.0000 - val_fn: 6663.0000 - val_accuracy: 0.5900 - val_precision: 0.5780 - val_recall: 0.6668 - val_auc: 0.6265
# Epoch 15/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6688 - tp: 132992.0000 - fp: 97159.0000 - tn: 102841.0000 - fn: 67008.0000 - accuracy: 0.5896 - precision: 0.5778 - recall: 0.6650 - auc: 0.6237 - val_loss: 0.6673 - val_tp: 14000.0000 - val_fp: 10637.0000 - val_tn: 9363.0000 - val_fn: 6000.0000 - val_accuracy: 0.5841 - val_precision: 0.5683 - val_recall: 0.7000 - val_auc: 0.6262
# Epoch 16/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6688 - tp: 133618.0000 - fp: 97928.0000 - tn: 102072.0000 - fn: 66382.0000 - accuracy: 0.5892 - precision: 0.5771 - recall: 0.6681 - auc: 0.6238 - val_loss: 0.6670 - val_tp: 14103.0000 - val_fp: 10578.0000 - val_tn: 9422.0000 - val_fn: 5897.0000 - val_accuracy: 0.5881 - val_precision: 0.5714 - val_recall: 0.7052 - val_auc: 0.6272
# Epoch 17/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6686 - tp: 134985.0000 - fp: 99047.0000 - tn: 100953.0000 - fn: 65015.0000 - accuracy: 0.5898 - precision: 0.5768 - recall: 0.6749 - auc: 0.6241 - val_loss: 0.6668 - val_tp: 13639.0000 - val_fp: 9969.0000 - val_tn: 10031.0000 - val_fn: 6361.0000 - val_accuracy: 0.5918 - val_precision: 0.5777 - val_recall: 0.6819 - val_auc: 0.6279
# Epoch 18/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6684 - tp: 135749.0000 - fp: 99689.0000 - tn: 100311.0000 - fn: 64251.0000 - accuracy: 0.5901 - precision: 0.5766 - recall: 0.6787 - auc: 0.6245 - val_loss: 0.6667 - val_tp: 13533.0000 - val_fp: 9961.0000 - val_tn: 10039.0000 - val_fn: 6467.0000 - val_accuracy: 0.5893 - val_precision: 0.5760 - val_recall: 0.6766 - val_auc: 0.6293
# Epoch 19/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6682 - tp: 135778.0000 - fp: 99521.0000 - tn: 100479.0000 - fn: 64222.0000 - accuracy: 0.5906 - precision: 0.5770 - recall: 0.6789 - auc: 0.6252 - val_loss: 0.6665 - val_tp: 13995.0000 - val_fp: 10382.0000 - val_tn: 9618.0000 - val_fn: 6005.0000 - val_accuracy: 0.5903 - val_precision: 0.5741 - val_recall: 0.6998 - val_auc: 0.6286
# Epoch 20/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6680 - tp: 135958.0000 - fp: 99696.0000 - tn: 100304.0000 - fn: 64042.0000 - accuracy: 0.5907 - precision: 0.5769 - recall: 0.6798 - auc: 0.6258 - val_loss: 0.6666 - val_tp: 13169.0000 - val_fp: 9626.0000 - val_tn: 10374.0000 - val_fn: 6831.0000 - val_accuracy: 0.5886 - val_precision: 0.5777 - val_recall: 0.6585 - val_auc: 0.6308
# Epoch 21/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6679 - tp: 135614.0000 - fp: 98975.0000 - tn: 101025.0000 - fn: 64386.0000 - accuracy: 0.5916 - precision: 0.5781 - recall: 0.6781 - auc: 0.6262 - val_loss: 0.6663 - val_tp: 14276.0000 - val_fp: 10627.0000 - val_tn: 9373.0000 - val_fn: 5724.0000 - val_accuracy: 0.5912 - val_precision: 0.5733 - val_recall: 0.7138 - val_auc: 0.6290
# Epoch 22/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6675 - tp: 136242.0000 - fp: 99755.0000 - tn: 100245.0000 - fn: 63758.0000 - accuracy: 0.5912 - precision: 0.5773 - recall: 0.6812 - auc: 0.6271 - val_loss: 0.6661 - val_tp: 13419.0000 - val_fp: 9707.0000 - val_tn: 10293.0000 - val_fn: 6581.0000 - val_accuracy: 0.5928 - val_precision: 0.5803 - val_recall: 0.6709 - val_auc: 0.6314
# Epoch 23/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6671 - tp: 136069.0000 - fp: 98897.0000 - tn: 101103.0000 - fn: 63931.0000 - accuracy: 0.5929 - precision: 0.5791 - recall: 0.6803 - auc: 0.6281 - val_loss: 0.6655 - val_tp: 13562.0000 - val_fp: 9817.0000 - val_tn: 10183.0000 - val_fn: 6438.0000 - val_accuracy: 0.5936 - val_precision: 0.5801 - val_recall: 0.6781 - val_auc: 0.6319
# Epoch 24/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6668 - tp: 135700.0000 - fp: 98183.0000 - tn: 101817.0000 - fn: 64300.0000 - accuracy: 0.5938 - precision: 0.5802 - recall: 0.6785 - auc: 0.6289 - val_loss: 0.6654 - val_tp: 13791.0000 - val_fp: 10108.0000 - val_tn: 9892.0000 - val_fn: 6209.0000 - val_accuracy: 0.5921 - val_precision: 0.5771 - val_recall: 0.6895 - val_auc: 0.6328
# Epoch 25/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6664 - tp: 135263.0000 - fp: 97578.0000 - tn: 102422.0000 - fn: 64737.0000 - accuracy: 0.5942 - precision: 0.5809 - recall: 0.6763 - auc: 0.6302 - val_loss: 0.6651 - val_tp: 13640.0000 - val_fp: 9963.0000 - val_tn: 10037.0000 - val_fn: 6360.0000 - val_accuracy: 0.5919 - val_precision: 0.5779 - val_recall: 0.6820 - val_auc: 0.6345
# Epoch 26/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6662 - tp: 136097.0000 - fp: 98063.0000 - tn: 101937.0000 - fn: 63903.0000 - accuracy: 0.5951 - precision: 0.5812 - recall: 0.6805 - auc: 0.6307 - val_loss: 0.6647 - val_tp: 13226.0000 - val_fp: 9406.0000 - val_tn: 10594.0000 - val_fn: 6774.0000 - val_accuracy: 0.5955 - val_precision: 0.5844 - val_recall: 0.6613 - val_auc: 0.6347
# Epoch 27/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6658 - tp: 135747.0000 - fp: 97355.0000 - tn: 102645.0000 - fn: 64253.0000 - accuracy: 0.5960 - precision: 0.5824 - recall: 0.6787 - auc: 0.6320 - val_loss: 0.6642 - val_tp: 12725.0000 - val_fp: 8779.0000 - val_tn: 11221.0000 - val_fn: 7275.0000 - val_accuracy: 0.5986 - val_precision: 0.5918 - val_recall: 0.6363 - val_auc: 0.6354
# Epoch 28/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6656 - tp: 135669.0000 - fp: 97246.0000 - tn: 102754.0000 - fn: 64331.0000 - accuracy: 0.5961 - precision: 0.5825 - recall: 0.6783 - auc: 0.6323 - val_loss: 0.6640 - val_tp: 13829.0000 - val_fp: 9989.0000 - val_tn: 10011.0000 - val_fn: 6171.0000 - val_accuracy: 0.5960 - val_precision: 0.5806 - val_recall: 0.6914 - val_auc: 0.6361
# Epoch 29/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6652 - tp: 134629.0000 - fp: 95698.0000 - tn: 104302.0000 - fn: 65371.0000 - accuracy: 0.5973 - precision: 0.5845 - recall: 0.6731 - auc: 0.6335 - val_loss: 0.6635 - val_tp: 14189.0000 - val_fp: 10068.0000 - val_tn: 9932.0000 - val_fn: 5811.0000 - val_accuracy: 0.6030 - val_precision: 0.5849 - val_recall: 0.7095 - val_auc: 0.6362
# Epoch 30/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6645 - tp: 134801.0000 - fp: 95466.0000 - tn: 104534.0000 - fn: 65199.0000 - accuracy: 0.5983 - precision: 0.5854 - recall: 0.6740 - auc: 0.6353 - val_loss: 0.6634 - val_tp: 13700.0000 - val_fp: 9687.0000 - val_tn: 10313.0000 - val_fn: 6300.0000 - val_accuracy: 0.6003 - val_precision: 0.5858 - val_recall: 0.6850 - val_auc: 0.6368
# Epoch 31/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6646 - tp: 134615.0000 - fp: 95253.0000 - tn: 104747.0000 - fn: 65385.0000 - accuracy: 0.5984 - precision: 0.5856 - recall: 0.6731 - auc: 0.6351 - val_loss: 0.6633 - val_tp: 14098.0000 - val_fp: 9854.0000 - val_tn: 10146.0000 - val_fn: 5902.0000 - val_accuracy: 0.6061 - val_precision: 0.5886 - val_recall: 0.7049 - val_auc: 0.6373
# Epoch 32/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6644 - tp: 134715.0000 - fp: 95240.0000 - tn: 104760.0000 - fn: 65285.0000 - accuracy: 0.5987 - precision: 0.5858 - recall: 0.6736 - auc: 0.6357 - val_loss: 0.6630 - val_tp: 13260.0000 - val_fp: 9184.0000 - val_tn: 10816.0000 - val_fn: 6740.0000 - val_accuracy: 0.6019 - val_precision: 0.5908 - val_recall: 0.6630 - val_auc: 0.6377
# Epoch 33/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6639 - tp: 133634.0000 - fp: 93755.0000 - tn: 106245.0000 - fn: 66366.0000 - accuracy: 0.5997 - precision: 0.5877 - recall: 0.6682 - auc: 0.6366 - val_loss: 0.6629 - val_tp: 13646.0000 - val_fp: 9539.0000 - val_tn: 10461.0000 - val_fn: 6354.0000 - val_accuracy: 0.6027 - val_precision: 0.5886 - val_recall: 0.6823 - val_auc: 0.6376
# Epoch 34/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6639 - tp: 133929.0000 - fp: 93970.0000 - tn: 106030.0000 - fn: 66071.0000 - accuracy: 0.5999 - precision: 0.5877 - recall: 0.6696 - auc: 0.6369 - val_loss: 0.6634 - val_tp: 13550.0000 - val_fp: 9411.0000 - val_tn: 10589.0000 - val_fn: 6450.0000 - val_accuracy: 0.6035 - val_precision: 0.5901 - val_recall: 0.6775 - val_auc: 0.6376
# Epoch 35/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6639 - tp: 134645.0000 - fp: 94890.0000 - tn: 105110.0000 - fn: 65355.0000 - accuracy: 0.5994 - precision: 0.5866 - recall: 0.6732 - auc: 0.6369 - val_loss: 0.6629 - val_tp: 13220.0000 - val_fp: 9146.0000 - val_tn: 10854.0000 - val_fn: 6780.0000 - val_accuracy: 0.6018 - val_precision: 0.5911 - val_recall: 0.6610 - val_auc: 0.6373
# Epoch 36/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6638 - tp: 134413.0000 - fp: 94611.0000 - tn: 105389.0000 - fn: 65587.0000 - accuracy: 0.5995 - precision: 0.5869 - recall: 0.6721 - auc: 0.6368 - val_loss: 0.6629 - val_tp: 13071.0000 - val_fp: 8920.0000 - val_tn: 11080.0000 - val_fn: 6929.0000 - val_accuracy: 0.6038 - val_precision: 0.5944 - val_recall: 0.6536 - val_auc: 0.6386
# Epoch 37/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6637 - tp: 134296.0000 - fp: 94373.0000 - tn: 105627.0000 - fn: 65704.0000 - accuracy: 0.5998 - precision: 0.5873 - recall: 0.6715 - auc: 0.6373 - val_loss: 0.6626 - val_tp: 13908.0000 - val_fp: 9693.0000 - val_tn: 10307.0000 - val_fn: 6092.0000 - val_accuracy: 0.6054 - val_precision: 0.5893 - val_recall: 0.6954 - val_auc: 0.6378
# Epoch 38/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6632 - tp: 134603.0000 - fp: 94657.0000 - tn: 105343.0000 - fn: 65397.0000 - accuracy: 0.5999 - precision: 0.5871 - recall: 0.6730 - auc: 0.6384 - val_loss: 0.6622 - val_tp: 13449.0000 - val_fp: 9239.0000 - val_tn: 10761.0000 - val_fn: 6551.0000 - val_accuracy: 0.6053 - val_precision: 0.5928 - val_recall: 0.6725 - val_auc: 0.6389
# Epoch 39/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6631 - tp: 133936.0000 - fp: 93752.0000 - tn: 106248.0000 - fn: 66064.0000 - accuracy: 0.6005 - precision: 0.5882 - recall: 0.6697 - auc: 0.6384 - val_loss: 0.6626 - val_tp: 13671.0000 - val_fp: 9570.0000 - val_tn: 10430.0000 - val_fn: 6329.0000 - val_accuracy: 0.6025 - val_precision: 0.5882 - val_recall: 0.6836 - val_auc: 0.6387
# Epoch 40/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6631 - tp: 134095.0000 - fp: 93892.0000 - tn: 106108.0000 - fn: 65905.0000 - accuracy: 0.6005 - precision: 0.5882 - recall: 0.6705 - auc: 0.6384 - val_loss: 0.6627 - val_tp: 13207.0000 - val_fp: 9125.0000 - val_tn: 10875.0000 - val_fn: 6793.0000 - val_accuracy: 0.6021 - val_precision: 0.5914 - val_recall: 0.6604 - val_auc: 0.6374
# Epoch 41/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6628 - tp: 133703.0000 - fp: 93456.0000 - tn: 106544.0000 - fn: 66297.0000 - accuracy: 0.6006 - precision: 0.5886 - recall: 0.6685 - auc: 0.6393 - val_loss: 0.6623 - val_tp: 13777.0000 - val_fp: 9633.0000 - val_tn: 10367.0000 - val_fn: 6223.0000 - val_accuracy: 0.6036 - val_precision: 0.5885 - val_recall: 0.6888 - val_auc: 0.6383
# Epoch 42/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6627 - tp: 133493.0000 - fp: 93410.0000 - tn: 106590.0000 - fn: 66507.0000 - accuracy: 0.6002 - precision: 0.5883 - recall: 0.6675 - auc: 0.6391 - val_loss: 0.6627 - val_tp: 13519.0000 - val_fp: 9454.0000 - val_tn: 10546.0000 - val_fn: 6481.0000 - val_accuracy: 0.6016 - val_precision: 0.5885 - val_recall: 0.6759 - val_auc: 0.6371
# Epoch 43/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6626 - tp: 134292.0000 - fp: 94132.0000 - tn: 105868.0000 - fn: 65708.0000 - accuracy: 0.6004 - precision: 0.5879 - recall: 0.6715 - auc: 0.6393 - val_loss: 0.6626 - val_tp: 13263.0000 - val_fp: 9078.0000 - val_tn: 10922.0000 - val_fn: 6737.0000 - val_accuracy: 0.6046 - val_precision: 0.5937 - val_recall: 0.6632 - val_auc: 0.6382
# Epoch 44/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6625 - tp: 133899.0000 - fp: 93654.0000 - tn: 106346.0000 - fn: 66101.0000 - accuracy: 0.6006 - precision: 0.5884 - recall: 0.6695 - auc: 0.6396 - val_loss: 0.6626 - val_tp: 13160.0000 - val_fp: 8998.0000 - val_tn: 11002.0000 - val_fn: 6840.0000 - val_accuracy: 0.6040 - val_precision: 0.5939 - val_recall: 0.6580 - val_auc: 0.6381
# Epoch 45/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6625 - tp: 133478.0000 - fp: 93409.0000 - tn: 106591.0000 - fn: 66522.0000 - accuracy: 0.6002 - precision: 0.5883 - recall: 0.6674 - auc: 0.6394 - val_loss: 0.6627 - val_tp: 13496.0000 - val_fp: 9287.0000 - val_tn: 10713.0000 - val_fn: 6504.0000 - val_accuracy: 0.6052 - val_precision: 0.5924 - val_recall: 0.6748 - val_auc: 0.6390
# Epoch 46/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6620 - tp: 133579.0000 - fp: 93052.0000 - tn: 106948.0000 - fn: 66421.0000 - accuracy: 0.6013 - precision: 0.5894 - recall: 0.6679 - auc: 0.6404 - val_loss: 0.6625 - val_tp: 13208.0000 - val_fp: 9065.0000 - val_tn: 10935.0000 - val_fn: 6792.0000 - val_accuracy: 0.6036 - val_precision: 0.5930 - val_recall: 0.6604 - val_auc: 0.6385
# Epoch 47/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6621 - tp: 133479.0000 - fp: 93204.0000 - tn: 106796.0000 - fn: 66521.0000 - accuracy: 0.6007 - precision: 0.5888 - recall: 0.6674 - auc: 0.6402 - val_loss: 0.6624 - val_tp: 13265.0000 - val_fp: 9159.0000 - val_tn: 10841.0000 - val_fn: 6735.0000 - val_accuracy: 0.6026 - val_precision: 0.5916 - val_recall: 0.6633 - val_auc: 0.6382
# Epoch 48/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6620 - tp: 133723.0000 - fp: 93219.0000 - tn: 106781.0000 - fn: 66277.0000 - accuracy: 0.6013 - precision: 0.5892 - recall: 0.6686 - auc: 0.6404 - val_loss: 0.6617 - val_tp: 13365.0000 - val_fp: 9219.0000 - val_tn: 10781.0000 - val_fn: 6635.0000 - val_accuracy: 0.6036 - val_precision: 0.5918 - val_recall: 0.6683 - val_auc: 0.6398
# Epoch 49/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6618 - tp: 132717.0000 - fp: 92277.0000 - tn: 107723.0000 - fn: 67283.0000 - accuracy: 0.6011 - precision: 0.5899 - recall: 0.6636 - auc: 0.6408 - val_loss: 0.6617 - val_tp: 13396.0000 - val_fp: 9465.0000 - val_tn: 10535.0000 - val_fn: 6604.0000 - val_accuracy: 0.5983 - val_precision: 0.5860 - val_recall: 0.6698 - val_auc: 0.6395
# Epoch 50/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6620 - tp: 133901.0000 - fp: 93347.0000 - tn: 106653.0000 - fn: 66099.0000 - accuracy: 0.6014 - precision: 0.5892 - recall: 0.6695 - auc: 0.6404 - val_loss: 0.6619 - val_tp: 13617.0000 - val_fp: 9579.0000 - val_tn: 10421.0000 - val_fn: 6383.0000 - val_accuracy: 0.6010 - val_precision: 0.5870 - val_recall: 0.6809 - val_auc: 0.6393
# Epoch 51/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6617 - tp: 133576.0000 - fp: 93109.0000 - tn: 106891.0000 - fn: 66424.0000 - accuracy: 0.6012 - precision: 0.5893 - recall: 0.6679 - auc: 0.6409 - val_loss: 0.6621 - val_tp: 13401.0000 - val_fp: 9220.0000 - val_tn: 10780.0000 - val_fn: 6599.0000 - val_accuracy: 0.6045 - val_precision: 0.5924 - val_recall: 0.6701 - val_auc: 0.6385
# Epoch 52/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6618 - tp: 134195.0000 - fp: 93886.0000 - tn: 106114.0000 - fn: 65805.0000 - accuracy: 0.6008 - precision: 0.5884 - recall: 0.6710 - auc: 0.6404 - val_loss: 0.6618 - val_tp: 14012.0000 - val_fp: 9892.0000 - val_tn: 10108.0000 - val_fn: 5988.0000 - val_accuracy: 0.6030 - val_precision: 0.5862 - val_recall: 0.7006 - val_auc: 0.6387
# Epoch 53/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6618 - tp: 134397.0000 - fp: 93736.0000 - tn: 106264.0000 - fn: 65603.0000 - accuracy: 0.6017 - precision: 0.5891 - recall: 0.6720 - auc: 0.6408 - val_loss: 0.6624 - val_tp: 13368.0000 - val_fp: 9354.0000 - val_tn: 10646.0000 - val_fn: 6632.0000 - val_accuracy: 0.6004 - val_precision: 0.5883 - val_recall: 0.6684 - val_auc: 0.6389
# Epoch 54/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6618 - tp: 134142.0000 - fp: 93952.0000 - tn: 106048.0000 - fn: 65858.0000 - accuracy: 0.6005 - precision: 0.5881 - recall: 0.6707 - auc: 0.6407 - val_loss: 0.6621 - val_tp: 13398.0000 - val_fp: 9199.0000 - val_tn: 10801.0000 - val_fn: 6602.0000 - val_accuracy: 0.6050 - val_precision: 0.5929 - val_recall: 0.6699 - val_auc: 0.6390
# Epoch 55/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6617 - tp: 134417.0000 - fp: 94072.0000 - tn: 105928.0000 - fn: 65583.0000 - accuracy: 0.6009 - precision: 0.5883 - recall: 0.6721 - auc: 0.6409 - val_loss: 0.6620 - val_tp: 13253.0000 - val_fp: 9028.0000 - val_tn: 10972.0000 - val_fn: 6747.0000 - val_accuracy: 0.6056 - val_precision: 0.5948 - val_recall: 0.6626 - val_auc: 0.6383
# Epoch 56/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6615 - tp: 134350.0000 - fp: 94064.0000 - tn: 105936.0000 - fn: 65650.0000 - accuracy: 0.6007 - precision: 0.5882 - recall: 0.6718 - auc: 0.6411 - val_loss: 0.6625 - val_tp: 13119.0000 - val_fp: 8899.0000 - val_tn: 11101.0000 - val_fn: 6881.0000 - val_accuracy: 0.6055 - val_precision: 0.5958 - val_recall: 0.6560 - val_auc: 0.6387
# Epoch 57/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6616 - tp: 134345.0000 - fp: 93855.0000 - tn: 106145.0000 - fn: 65655.0000 - accuracy: 0.6012 - precision: 0.5887 - recall: 0.6717 - auc: 0.6407 - val_loss: 0.6615 - val_tp: 13755.0000 - val_fp: 9644.0000 - val_tn: 10356.0000 - val_fn: 6245.0000 - val_accuracy: 0.6028 - val_precision: 0.5878 - val_recall: 0.6877 - val_auc: 0.6403
# Epoch 58/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6612 - tp: 134311.0000 - fp: 93803.0000 - tn: 106197.0000 - fn: 65689.0000 - accuracy: 0.6013 - precision: 0.5888 - recall: 0.6716 - auc: 0.6418 - val_loss: 0.6619 - val_tp: 13495.0000 - val_fp: 9353.0000 - val_tn: 10647.0000 - val_fn: 6505.0000 - val_accuracy: 0.6036 - val_precision: 0.5906 - val_recall: 0.6747 - val_auc: 0.6394
# Epoch 59/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6613 - tp: 134289.0000 - fp: 93859.0000 - tn: 106141.0000 - fn: 65711.0000 - accuracy: 0.6011 - precision: 0.5886 - recall: 0.6714 - auc: 0.6413 - val_loss: 0.6620 - val_tp: 13107.0000 - val_fp: 8880.0000 - val_tn: 11120.0000 - val_fn: 6893.0000 - val_accuracy: 0.6057 - val_precision: 0.5961 - val_recall: 0.6554 - val_auc: 0.6396
# Epoch 60/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6612 - tp: 134995.0000 - fp: 94222.0000 - tn: 105778.0000 - fn: 65005.0000 - accuracy: 0.6019 - precision: 0.5889 - recall: 0.6750 - auc: 0.6418 - val_loss: 0.6618 - val_tp: 13281.0000 - val_fp: 9226.0000 - val_tn: 10774.0000 - val_fn: 6719.0000 - val_accuracy: 0.6014 - val_precision: 0.5901 - val_recall: 0.6640 - val_auc: 0.6398
# Epoch 61/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6612 - tp: 134004.0000 - fp: 93707.0000 - tn: 106293.0000 - fn: 65996.0000 - accuracy: 0.6007 - precision: 0.5885 - recall: 0.6700 - auc: 0.6413 - val_loss: 0.6612 - val_tp: 13575.0000 - val_fp: 9359.0000 - val_tn: 10641.0000 - val_fn: 6425.0000 - val_accuracy: 0.6054 - val_precision: 0.5919 - val_recall: 0.6787 - val_auc: 0.6401
# Epoch 62/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6613 - tp: 135114.0000 - fp: 94607.0000 - tn: 105393.0000 - fn: 64886.0000 - accuracy: 0.6013 - precision: 0.5882 - recall: 0.6756 - auc: 0.6413 - val_loss: 0.6616 - val_tp: 13364.0000 - val_fp: 9115.0000 - val_tn: 10885.0000 - val_fn: 6636.0000 - val_accuracy: 0.6062 - val_precision: 0.5945 - val_recall: 0.6682 - val_auc: 0.6406
# Epoch 63/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6610 - tp: 134505.0000 - fp: 94001.0000 - tn: 105999.0000 - fn: 65495.0000 - accuracy: 0.6013 - precision: 0.5886 - recall: 0.6725 - auc: 0.6418 - val_loss: 0.6616 - val_tp: 14178.0000 - val_fp: 10072.0000 - val_tn: 9928.0000 - val_fn: 5822.0000 - val_accuracy: 0.6026 - val_precision: 0.5847 - val_recall: 0.7089 - val_auc: 0.6407
# Epoch 64/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6612 - tp: 134690.0000 - fp: 94266.0000 - tn: 105734.0000 - fn: 65310.0000 - accuracy: 0.6011 - precision: 0.5883 - recall: 0.6734 - auc: 0.6416 - val_loss: 0.6612 - val_tp: 13686.0000 - val_fp: 9250.0000 - val_tn: 10750.0000 - val_fn: 6314.0000 - val_accuracy: 0.6109 - val_precision: 0.5967 - val_recall: 0.6843 - val_auc: 0.6408
# Epoch 65/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6609 - tp: 134713.0000 - fp: 94155.0000 - tn: 105845.0000 - fn: 65287.0000 - accuracy: 0.6014 - precision: 0.5886 - recall: 0.6736 - auc: 0.6421 - val_loss: 0.6614 - val_tp: 13381.0000 - val_fp: 9191.0000 - val_tn: 10809.0000 - val_fn: 6619.0000 - val_accuracy: 0.6047 - val_precision: 0.5928 - val_recall: 0.6690 - val_auc: 0.6405
# Epoch 66/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6612 - tp: 134855.0000 - fp: 94658.0000 - tn: 105342.0000 - fn: 65145.0000 - accuracy: 0.6005 - precision: 0.5876 - recall: 0.6743 - auc: 0.6414 - val_loss: 0.6606 - val_tp: 13236.0000 - val_fp: 9057.0000 - val_tn: 10943.0000 - val_fn: 6764.0000 - val_accuracy: 0.6045 - val_precision: 0.5937 - val_recall: 0.6618 - val_auc: 0.6413
# Epoch 67/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6608 - tp: 134312.0000 - fp: 93707.0000 - tn: 106293.0000 - fn: 65688.0000 - accuracy: 0.6015 - precision: 0.5890 - recall: 0.6716 - auc: 0.6423 - val_loss: 0.6605 - val_tp: 13528.0000 - val_fp: 9298.0000 - val_tn: 10702.0000 - val_fn: 6472.0000 - val_accuracy: 0.6058 - val_precision: 0.5927 - val_recall: 0.6764 - val_auc: 0.6413
# Epoch 68/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6606 - tp: 135659.0000 - fp: 95175.0000 - tn: 104825.0000 - fn: 64341.0000 - accuracy: 0.6012 - precision: 0.5877 - recall: 0.6783 - auc: 0.6423 - val_loss: 0.6614 - val_tp: 13421.0000 - val_fp: 9162.0000 - val_tn: 10838.0000 - val_fn: 6579.0000 - val_accuracy: 0.6065 - val_precision: 0.5943 - val_recall: 0.6711 - val_auc: 0.6404
# Epoch 69/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6609 - tp: 134566.0000 - fp: 94175.0000 - tn: 105825.0000 - fn: 65434.0000 - accuracy: 0.6010 - precision: 0.5883 - recall: 0.6728 - auc: 0.6420 - val_loss: 0.6610 - val_tp: 13964.0000 - val_fp: 9777.0000 - val_tn: 10223.0000 - val_fn: 6036.0000 - val_accuracy: 0.6047 - val_precision: 0.5882 - val_recall: 0.6982 - val_auc: 0.6409
# Epoch 70/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6607 - tp: 135546.0000 - fp: 95099.0000 - tn: 104901.0000 - fn: 64454.0000 - accuracy: 0.6011 - precision: 0.5877 - recall: 0.6777 - auc: 0.6423 - val_loss: 0.6618 - val_tp: 13270.0000 - val_fp: 9089.0000 - val_tn: 10911.0000 - val_fn: 6730.0000 - val_accuracy: 0.6045 - val_precision: 0.5935 - val_recall: 0.6635 - val_auc: 0.6405
# Epoch 71/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6602 - tp: 134673.0000 - fp: 93538.0000 - tn: 106462.0000 - fn: 65327.0000 - accuracy: 0.6028 - precision: 0.5901 - recall: 0.6734 - auc: 0.6436 - val_loss: 0.6610 - val_tp: 12908.0000 - val_fp: 8910.0000 - val_tn: 11090.0000 - val_fn: 7092.0000 - val_accuracy: 0.6000 - val_precision: 0.5916 - val_recall: 0.6454 - val_auc: 0.6413
# Epoch 72/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6604 - tp: 134420.0000 - fp: 93774.0000 - tn: 106226.0000 - fn: 65580.0000 - accuracy: 0.6016 - precision: 0.5891 - recall: 0.6721 - auc: 0.6432 - val_loss: 0.6609 - val_tp: 13875.0000 - val_fp: 9647.0000 - val_tn: 10353.0000 - val_fn: 6125.0000 - val_accuracy: 0.6057 - val_precision: 0.5899 - val_recall: 0.6938 - val_auc: 0.6411
# Epoch 73/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6606 - tp: 135338.0000 - fp: 94615.0000 - tn: 105385.0000 - fn: 64662.0000 - accuracy: 0.6018 - precision: 0.5885 - recall: 0.6767 - auc: 0.6426 - val_loss: 0.6611 - val_tp: 14026.0000 - val_fp: 9633.0000 - val_tn: 10367.0000 - val_fn: 5974.0000 - val_accuracy: 0.6098 - val_precision: 0.5928 - val_recall: 0.7013 - val_auc: 0.6410
# Epoch 74/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6603 - tp: 135617.0000 - fp: 94916.0000 - tn: 105084.0000 - fn: 64383.0000 - accuracy: 0.6018 - precision: 0.5883 - recall: 0.6781 - auc: 0.6429 - val_loss: 0.6608 - val_tp: 13287.0000 - val_fp: 8861.0000 - val_tn: 11139.0000 - val_fn: 6713.0000 - val_accuracy: 0.6107 - val_precision: 0.5999 - val_recall: 0.6643 - val_auc: 0.6419
# Epoch 75/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6603 - tp: 134505.0000 - fp: 93702.0000 - tn: 106298.0000 - fn: 65495.0000 - accuracy: 0.6020 - precision: 0.5894 - recall: 0.6725 - auc: 0.6430 - val_loss: 0.6607 - val_tp: 13215.0000 - val_fp: 9021.0000 - val_tn: 10979.0000 - val_fn: 6785.0000 - val_accuracy: 0.6048 - val_precision: 0.5943 - val_recall: 0.6607 - val_auc: 0.6420
# Epoch 76/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6601 - tp: 134578.0000 - fp: 93748.0000 - tn: 106252.0000 - fn: 65422.0000 - accuracy: 0.6021 - precision: 0.5894 - recall: 0.6729 - auc: 0.6436 - val_loss: 0.6609 - val_tp: 13963.0000 - val_fp: 9771.0000 - val_tn: 10229.0000 - val_fn: 6037.0000 - val_accuracy: 0.6048 - val_precision: 0.5883 - val_recall: 0.6981 - val_auc: 0.6419
# Epoch 77/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6604 - tp: 134143.0000 - fp: 93379.0000 - tn: 106621.0000 - fn: 65857.0000 - accuracy: 0.6019 - precision: 0.5896 - recall: 0.6707 - auc: 0.6430 - val_loss: 0.6606 - val_tp: 14329.0000 - val_fp: 10088.0000 - val_tn: 9912.0000 - val_fn: 5671.0000 - val_accuracy: 0.6060 - val_precision: 0.5868 - val_recall: 0.7164 - val_auc: 0.6420
# Epoch 78/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6601 - tp: 135116.0000 - fp: 94192.0000 - tn: 105808.0000 - fn: 64884.0000 - accuracy: 0.6023 - precision: 0.5892 - recall: 0.6756 - auc: 0.6436 - val_loss: 0.6606 - val_tp: 13580.0000 - val_fp: 9336.0000 - val_tn: 10664.0000 - val_fn: 6420.0000 - val_accuracy: 0.6061 - val_precision: 0.5926 - val_recall: 0.6790 - val_auc: 0.6421
# Epoch 79/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6598 - tp: 134272.0000 - fp: 93636.0000 - tn: 106364.0000 - fn: 65728.0000 - accuracy: 0.6016 - precision: 0.5892 - recall: 0.6714 - auc: 0.6444 - val_loss: 0.6604 - val_tp: 13786.0000 - val_fp: 9423.0000 - val_tn: 10577.0000 - val_fn: 6214.0000 - val_accuracy: 0.6091 - val_precision: 0.5940 - val_recall: 0.6893 - val_auc: 0.6426
# Epoch 80/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6601 - tp: 134401.0000 - fp: 93577.0000 - tn: 106423.0000 - fn: 65599.0000 - accuracy: 0.6021 - precision: 0.5895 - recall: 0.6720 - auc: 0.6433 - val_loss: 0.6611 - val_tp: 13542.0000 - val_fp: 9302.0000 - val_tn: 10698.0000 - val_fn: 6458.0000 - val_accuracy: 0.6060 - val_precision: 0.5928 - val_recall: 0.6771 - val_auc: 0.6418
# Epoch 81/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6601 - tp: 134163.0000 - fp: 93308.0000 - tn: 106692.0000 - fn: 65837.0000 - accuracy: 0.6021 - precision: 0.5898 - recall: 0.6708 - auc: 0.6434 - val_loss: 0.6609 - val_tp: 13689.0000 - val_fp: 9252.0000 - val_tn: 10748.0000 - val_fn: 6311.0000 - val_accuracy: 0.6109 - val_precision: 0.5967 - val_recall: 0.6844 - val_auc: 0.6416
# Epoch 82/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6598 - tp: 134741.0000 - fp: 93915.0000 - tn: 106085.0000 - fn: 65259.0000 - accuracy: 0.6021 - precision: 0.5893 - recall: 0.6737 - auc: 0.6439 - val_loss: 0.6609 - val_tp: 13502.0000 - val_fp: 9239.0000 - val_tn: 10761.0000 - val_fn: 6498.0000 - val_accuracy: 0.6066 - val_precision: 0.5937 - val_recall: 0.6751 - val_auc: 0.6416
# Epoch 83/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6601 - tp: 134679.0000 - fp: 94179.0000 - tn: 105821.0000 - fn: 65321.0000 - accuracy: 0.6012 - precision: 0.5885 - recall: 0.6734 - auc: 0.6431 - val_loss: 0.6603 - val_tp: 13820.0000 - val_fp: 9362.0000 - val_tn: 10638.0000 - val_fn: 6180.0000 - val_accuracy: 0.6115 - val_precision: 0.5962 - val_recall: 0.6910 - val_auc: 0.6422
# Epoch 84/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6600 - tp: 134522.0000 - fp: 93810.0000 - tn: 106190.0000 - fn: 65478.0000 - accuracy: 0.6018 - precision: 0.5892 - recall: 0.6726 - auc: 0.6435 - val_loss: 0.6606 - val_tp: 13640.0000 - val_fp: 9178.0000 - val_tn: 10822.0000 - val_fn: 6360.0000 - val_accuracy: 0.6115 - val_precision: 0.5978 - val_recall: 0.6820 - val_auc: 0.6423
# Epoch 85/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6599 - tp: 134391.0000 - fp: 93612.0000 - tn: 106388.0000 - fn: 65609.0000 - accuracy: 0.6019 - precision: 0.5894 - recall: 0.6720 - auc: 0.6434 - val_loss: 0.6606 - val_tp: 13196.0000 - val_fp: 8958.0000 - val_tn: 11042.0000 - val_fn: 6804.0000 - val_accuracy: 0.6059 - val_precision: 0.5956 - val_recall: 0.6598 - val_auc: 0.6421
# Epoch 86/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6598 - tp: 134910.0000 - fp: 94011.0000 - tn: 105989.0000 - fn: 65090.0000 - accuracy: 0.6022 - precision: 0.5893 - recall: 0.6745 - auc: 0.6438 - val_loss: 0.6607 - val_tp: 13185.0000 - val_fp: 9026.0000 - val_tn: 10974.0000 - val_fn: 6815.0000 - val_accuracy: 0.6040 - val_precision: 0.5936 - val_recall: 0.6593 - val_auc: 0.6422
# Epoch 87/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6597 - tp: 134525.0000 - fp: 93602.0000 - tn: 106398.0000 - fn: 65475.0000 - accuracy: 0.6023 - precision: 0.5897 - recall: 0.6726 - auc: 0.6443 - val_loss: 0.6603 - val_tp: 14133.0000 - val_fp: 9675.0000 - val_tn: 10325.0000 - val_fn: 5867.0000 - val_accuracy: 0.6115 - val_precision: 0.5936 - val_recall: 0.7067 - val_auc: 0.6424
# Epoch 88/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6597 - tp: 134029.0000 - fp: 93216.0000 - tn: 106784.0000 - fn: 65971.0000 - accuracy: 0.6020 - precision: 0.5898 - recall: 0.6701 - auc: 0.6440 - val_loss: 0.6604 - val_tp: 14098.0000 - val_fp: 9592.0000 - val_tn: 10408.0000 - val_fn: 5902.0000 - val_accuracy: 0.6126 - val_precision: 0.5951 - val_recall: 0.7049 - val_auc: 0.6426
# Epoch 89/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6595 - tp: 134460.0000 - fp: 93485.0000 - tn: 106515.0000 - fn: 65540.0000 - accuracy: 0.6024 - precision: 0.5899 - recall: 0.6723 - auc: 0.6444 - val_loss: 0.6605 - val_tp: 13787.0000 - val_fp: 9315.0000 - val_tn: 10685.0000 - val_fn: 6213.0000 - val_accuracy: 0.6118 - val_precision: 0.5968 - val_recall: 0.6894 - val_auc: 0.6428
# Epoch 90/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6596 - tp: 134188.0000 - fp: 93468.0000 - tn: 106532.0000 - fn: 65812.0000 - accuracy: 0.6018 - precision: 0.5894 - recall: 0.6709 - auc: 0.6440 - val_loss: 0.6607 - val_tp: 13742.0000 - val_fp: 9318.0000 - val_tn: 10682.0000 - val_fn: 6258.0000 - val_accuracy: 0.6106 - val_precision: 0.5959 - val_recall: 0.6871 - val_auc: 0.6428
# Epoch 91/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6597 - tp: 134463.0000 - fp: 93835.0000 - tn: 106165.0000 - fn: 65537.0000 - accuracy: 0.6016 - precision: 0.5890 - recall: 0.6723 - auc: 0.6440 - val_loss: 0.6607 - val_tp: 14092.0000 - val_fp: 9815.0000 - val_tn: 10185.0000 - val_fn: 5908.0000 - val_accuracy: 0.6069 - val_precision: 0.5895 - val_recall: 0.7046 - val_auc: 0.6424
# Epoch 92/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6597 - tp: 134532.0000 - fp: 93704.0000 - tn: 106296.0000 - fn: 65468.0000 - accuracy: 0.6021 - precision: 0.5894 - recall: 0.6727 - auc: 0.6436 - val_loss: 0.6604 - val_tp: 13594.0000 - val_fp: 9141.0000 - val_tn: 10859.0000 - val_fn: 6406.0000 - val_accuracy: 0.6113 - val_precision: 0.5979 - val_recall: 0.6797 - val_auc: 0.6426
# Epoch 93/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6594 - tp: 133398.0000 - fp: 92544.0000 - tn: 107456.0000 - fn: 66602.0000 - accuracy: 0.6021 - precision: 0.5904 - recall: 0.6670 - auc: 0.6445 - val_loss: 0.6602 - val_tp: 13451.0000 - val_fp: 9158.0000 - val_tn: 10842.0000 - val_fn: 6549.0000 - val_accuracy: 0.6073 - val_precision: 0.5949 - val_recall: 0.6726 - val_auc: 0.6428
# Epoch 94/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6594 - tp: 133953.0000 - fp: 93006.0000 - tn: 106994.0000 - fn: 66047.0000 - accuracy: 0.6024 - precision: 0.5902 - recall: 0.6698 - auc: 0.6446 - val_loss: 0.6604 - val_tp: 13841.0000 - val_fp: 9457.0000 - val_tn: 10543.0000 - val_fn: 6159.0000 - val_accuracy: 0.6096 - val_precision: 0.5941 - val_recall: 0.6920 - val_auc: 0.6430
# Epoch 95/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6595 - tp: 134214.0000 - fp: 93453.0000 - tn: 106547.0000 - fn: 65786.0000 - accuracy: 0.6019 - precision: 0.5895 - recall: 0.6711 - auc: 0.6445 - val_loss: 0.6598 - val_tp: 13672.0000 - val_fp: 9196.0000 - val_tn: 10804.0000 - val_fn: 6328.0000 - val_accuracy: 0.6119 - val_precision: 0.5979 - val_recall: 0.6836 - val_auc: 0.6436
# Epoch 96/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6593 - tp: 133603.0000 - fp: 92729.0000 - tn: 107271.0000 - fn: 66397.0000 - accuracy: 0.6022 - precision: 0.5903 - recall: 0.6680 - auc: 0.6447 - val_loss: 0.6603 - val_tp: 13874.0000 - val_fp: 9397.0000 - val_tn: 10603.0000 - val_fn: 6126.0000 - val_accuracy: 0.6119 - val_precision: 0.5962 - val_recall: 0.6937 - val_auc: 0.6433
# Epoch 97/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6596 - tp: 134246.0000 - fp: 93448.0000 - tn: 106552.0000 - fn: 65754.0000 - accuracy: 0.6020 - precision: 0.5896 - recall: 0.6712 - auc: 0.6443 - val_loss: 0.6600 - val_tp: 13736.0000 - val_fp: 9258.0000 - val_tn: 10742.0000 - val_fn: 6264.0000 - val_accuracy: 0.6119 - val_precision: 0.5974 - val_recall: 0.6868 - val_auc: 0.6440
# Epoch 98/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6594 - tp: 133586.0000 - fp: 92620.0000 - tn: 107380.0000 - fn: 66414.0000 - accuracy: 0.6024 - precision: 0.5906 - recall: 0.6679 - auc: 0.6446 - val_loss: 0.6606 - val_tp: 13883.0000 - val_fp: 9386.0000 - val_tn: 10614.0000 - val_fn: 6117.0000 - val_accuracy: 0.6124 - val_precision: 0.5966 - val_recall: 0.6941 - val_auc: 0.6427
# Epoch 99/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6592 - tp: 133617.0000 - fp: 92635.0000 - tn: 107365.0000 - fn: 66383.0000 - accuracy: 0.6025 - precision: 0.5906 - recall: 0.6681 - auc: 0.6448 - val_loss: 0.6613 - val_tp: 13242.0000 - val_fp: 8886.0000 - val_tn: 11114.0000 - val_fn: 6758.0000 - val_accuracy: 0.6089 - val_precision: 0.5984 - val_recall: 0.6621 - val_auc: 0.6416
# Epoch 100/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6592 - tp: 133530.0000 - fp: 92681.0000 - tn: 107319.0000 - fn: 66470.0000 - accuracy: 0.6021 - precision: 0.5903 - recall: 0.6676 - auc: 0.6450 - val_loss: 0.6598 - val_tp: 14082.0000 - val_fp: 9724.0000 - val_tn: 10276.0000 - val_fn: 5918.0000 - val_accuracy: 0.6090 - val_precision: 0.5915 - val_recall: 0.7041 - val_auc: 0.6437
# Epoch 101/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6591 - tp: 133512.0000 - fp: 92570.0000 - tn: 107430.0000 - fn: 66488.0000 - accuracy: 0.6024 - precision: 0.5905 - recall: 0.6676 - auc: 0.6450 - val_loss: 0.6605 - val_tp: 13175.0000 - val_fp: 8943.0000 - val_tn: 11057.0000 - val_fn: 6825.0000 - val_accuracy: 0.6058 - val_precision: 0.5957 - val_recall: 0.6587 - val_auc: 0.6428
# Epoch 102/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6591 - tp: 134134.0000 - fp: 93157.0000 - tn: 106843.0000 - fn: 65866.0000 - accuracy: 0.6024 - precision: 0.5901 - recall: 0.6707 - auc: 0.6453 - val_loss: 0.6601 - val_tp: 13909.0000 - val_fp: 9444.0000 - val_tn: 10556.0000 - val_fn: 6091.0000 - val_accuracy: 0.6116 - val_precision: 0.5956 - val_recall: 0.6955 - val_auc: 0.6433
# Epoch 103/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6594 - tp: 133789.0000 - fp: 92904.0000 - tn: 107096.0000 - fn: 66211.0000 - accuracy: 0.6022 - precision: 0.5902 - recall: 0.6689 - auc: 0.6447 - val_loss: 0.6594 - val_tp: 14005.0000 - val_fp: 9449.0000 - val_tn: 10551.0000 - val_fn: 5995.0000 - val_accuracy: 0.6139 - val_precision: 0.5971 - val_recall: 0.7003 - val_auc: 0.6448
# Epoch 104/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6592 - tp: 134003.0000 - fp: 93148.0000 - tn: 106852.0000 - fn: 65997.0000 - accuracy: 0.6021 - precision: 0.5899 - recall: 0.6700 - auc: 0.6447 - val_loss: 0.6596 - val_tp: 13751.0000 - val_fp: 9414.0000 - val_tn: 10586.0000 - val_fn: 6249.0000 - val_accuracy: 0.6084 - val_precision: 0.5936 - val_recall: 0.6876 - val_auc: 0.6439
# Epoch 105/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6589 - tp: 133255.0000 - fp: 91924.0000 - tn: 108076.0000 - fn: 66745.0000 - accuracy: 0.6033 - precision: 0.5918 - recall: 0.6663 - auc: 0.6457 - val_loss: 0.6599 - val_tp: 13580.0000 - val_fp: 9196.0000 - val_tn: 10804.0000 - val_fn: 6420.0000 - val_accuracy: 0.6096 - val_precision: 0.5962 - val_recall: 0.6790 - val_auc: 0.6439
# Epoch 106/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6590 - tp: 133048.0000 - fp: 91872.0000 - tn: 108128.0000 - fn: 66952.0000 - accuracy: 0.6029 - precision: 0.5915 - recall: 0.6652 - auc: 0.6456 - val_loss: 0.6600 - val_tp: 13907.0000 - val_fp: 9373.0000 - val_tn: 10627.0000 - val_fn: 6093.0000 - val_accuracy: 0.6133 - val_precision: 0.5974 - val_recall: 0.6953 - val_auc: 0.6438
# Epoch 107/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6588 - tp: 132858.0000 - fp: 91819.0000 - tn: 108181.0000 - fn: 67142.0000 - accuracy: 0.6026 - precision: 0.5913 - recall: 0.6643 - auc: 0.6456 - val_loss: 0.6604 - val_tp: 14218.0000 - val_fp: 9796.0000 - val_tn: 10204.0000 - val_fn: 5782.0000 - val_accuracy: 0.6105 - val_precision: 0.5921 - val_recall: 0.7109 - val_auc: 0.6433
# Epoch 108/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6589 - tp: 133106.0000 - fp: 91765.0000 - tn: 108235.0000 - fn: 66894.0000 - accuracy: 0.6034 - precision: 0.5919 - recall: 0.6655 - auc: 0.6456 - val_loss: 0.6599 - val_tp: 13679.0000 - val_fp: 9370.0000 - val_tn: 10630.0000 - val_fn: 6321.0000 - val_accuracy: 0.6077 - val_precision: 0.5935 - val_recall: 0.6840 - val_auc: 0.6445
# Epoch 109/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6588 - tp: 133493.0000 - fp: 92171.0000 - tn: 107829.0000 - fn: 66507.0000 - accuracy: 0.6033 - precision: 0.5916 - recall: 0.6675 - auc: 0.6456 - val_loss: 0.6599 - val_tp: 13376.0000 - val_fp: 9057.0000 - val_tn: 10943.0000 - val_fn: 6624.0000 - val_accuracy: 0.6080 - val_precision: 0.5963 - val_recall: 0.6688 - val_auc: 0.6444
# Epoch 110/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6587 - tp: 133204.0000 - fp: 91903.0000 - tn: 108097.0000 - fn: 66796.0000 - accuracy: 0.6033 - precision: 0.5917 - recall: 0.6660 - auc: 0.6459 - val_loss: 0.6597 - val_tp: 13558.0000 - val_fp: 9248.0000 - val_tn: 10752.0000 - val_fn: 6442.0000 - val_accuracy: 0.6077 - val_precision: 0.5945 - val_recall: 0.6779 - val_auc: 0.6442
# Epoch 111/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6588 - tp: 132597.0000 - fp: 91665.0000 - tn: 108335.0000 - fn: 67403.0000 - accuracy: 0.6023 - precision: 0.5913 - recall: 0.6630 - auc: 0.6455 - val_loss: 0.6603 - val_tp: 13533.0000 - val_fp: 9196.0000 - val_tn: 10804.0000 - val_fn: 6467.0000 - val_accuracy: 0.6084 - val_precision: 0.5954 - val_recall: 0.6766 - val_auc: 0.6429
# Epoch 112/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6586 - tp: 132303.0000 - fp: 91191.0000 - tn: 108809.0000 - fn: 67697.0000 - accuracy: 0.6028 - precision: 0.5920 - recall: 0.6615 - auc: 0.6458 - val_loss: 0.6601 - val_tp: 13265.0000 - val_fp: 9160.0000 - val_tn: 10840.0000 - val_fn: 6735.0000 - val_accuracy: 0.6026 - val_precision: 0.5915 - val_recall: 0.6633 - val_auc: 0.6431
# Epoch 113/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6588 - tp: 132494.0000 - fp: 91639.0000 - tn: 108361.0000 - fn: 67506.0000 - accuracy: 0.6021 - precision: 0.5911 - recall: 0.6625 - auc: 0.6456 - val_loss: 0.6592 - val_tp: 13827.0000 - val_fp: 9386.0000 - val_tn: 10614.0000 - val_fn: 6173.0000 - val_accuracy: 0.6110 - val_precision: 0.5957 - val_recall: 0.6913 - val_auc: 0.6446
# Epoch 114/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6588 - tp: 133141.0000 - fp: 91997.0000 - tn: 108003.0000 - fn: 66859.0000 - accuracy: 0.6029 - precision: 0.5914 - recall: 0.6657 - auc: 0.6456 - val_loss: 0.6600 - val_tp: 13097.0000 - val_fp: 8932.0000 - val_tn: 11068.0000 - val_fn: 6903.0000 - val_accuracy: 0.6041 - val_precision: 0.5945 - val_recall: 0.6549 - val_auc: 0.6445
# Epoch 115/200
# ...
# Epoch 163/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6569 - tp: 130923.0000 - fp: 89036.0000 - tn: 110964.0000 - fn: 69077.0000 - accuracy: 0.6047 - precision: 0.5952 - recall: 0.6546 - auc: 0.6491 - val_loss: 0.6594 - val_tp: 13414.0000 - val_fp: 9067.0000 - val_tn: 10933.0000 - val_fn: 6586.0000 - val_accuracy: 0.6087 - val_precision: 0.5967 - val_recall: 0.6707 - val_auc: 0.6464
# Epoch 164/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6566 - tp: 130624.0000 - fp: 88568.0000 - tn: 111432.0000 - fn: 69376.0000 - accuracy: 0.6051 - precision: 0.5959 - recall: 0.6531 - auc: 0.6496 - val_loss: 0.6588 - val_tp: 13383.0000 - val_fp: 8936.0000 - val_tn: 11064.0000 - val_fn: 6617.0000 - val_accuracy: 0.6112 - val_precision: 0.5996 - val_recall: 0.6691 - val_auc: 0.6469
# Epoch 165/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6567 - tp: 130418.0000 - fp: 88404.0000 - tn: 111596.0000 - fn: 69582.0000 - accuracy: 0.6050 - precision: 0.5960 - recall: 0.6521 - auc: 0.6495 - val_loss: 0.6587 - val_tp: 13453.0000 - val_fp: 9001.0000 - val_tn: 10999.0000 - val_fn: 6547.0000 - val_accuracy: 0.6113 - val_precision: 0.5991 - val_recall: 0.6726 - val_auc: 0.6467
# Epoch 166/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6567 - tp: 130807.0000 - fp: 88893.0000 - tn: 111107.0000 - fn: 69193.0000 - accuracy: 0.6048 - precision: 0.5954 - recall: 0.6540 - auc: 0.6496 - val_loss: 0.6581 - val_tp: 13681.0000 - val_fp: 9252.0000 - val_tn: 10748.0000 - val_fn: 6319.0000 - val_accuracy: 0.6107 - val_precision: 0.5966 - val_recall: 0.6841 - val_auc: 0.6478
# Epoch 167/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6571 - tp: 130609.0000 - fp: 88664.0000 - tn: 111336.0000 - fn: 69391.0000 - accuracy: 0.6049 - precision: 0.5956 - recall: 0.6530 - auc: 0.6486 - val_loss: 0.6586 - val_tp: 13379.0000 - val_fp: 8840.0000 - val_tn: 11160.0000 - val_fn: 6621.0000 - val_accuracy: 0.6135 - val_precision: 0.6021 - val_recall: 0.6690 - val_auc: 0.6475
# Epoch 168/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6572 - tp: 130216.0000 - fp: 88344.0000 - tn: 111656.0000 - fn: 69784.0000 - accuracy: 0.6047 - precision: 0.5958 - recall: 0.6511 - auc: 0.6486 - val_loss: 0.6586 - val_tp: 13389.0000 - val_fp: 8924.0000 - val_tn: 11076.0000 - val_fn: 6611.0000 - val_accuracy: 0.6116 - val_precision: 0.6001 - val_recall: 0.6694 - val_auc: 0.6463
# Epoch 169/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6567 - tp: 130797.0000 - fp: 88850.0000 - tn: 111150.0000 - fn: 69203.0000 - accuracy: 0.6049 - precision: 0.5955 - recall: 0.6540 - auc: 0.6494 - val_loss: 0.6586 - val_tp: 13081.0000 - val_fp: 8774.0000 - val_tn: 11226.0000 - val_fn: 6919.0000 - val_accuracy: 0.6077 - val_precision: 0.5985 - val_recall: 0.6540 - val_auc: 0.6466
# Epoch 170/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6567 - tp: 130444.0000 - fp: 88472.0000 - tn: 111528.0000 - fn: 69556.0000 - accuracy: 0.6049 - precision: 0.5959 - recall: 0.6522 - auc: 0.6496 - val_loss: 0.6580 - val_tp: 13853.0000 - val_fp: 9413.0000 - val_tn: 10587.0000 - val_fn: 6147.0000 - val_accuracy: 0.6110 - val_precision: 0.5954 - val_recall: 0.6927 - val_auc: 0.6476
# Epoch 171/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6570 - tp: 130503.0000 - fp: 88760.0000 - tn: 111240.0000 - fn: 69497.0000 - accuracy: 0.6044 - precision: 0.5952 - recall: 0.6525 - auc: 0.6487 - val_loss: 0.6581 - val_tp: 13619.0000 - val_fp: 9199.0000 - val_tn: 10801.0000 - val_fn: 6381.0000 - val_accuracy: 0.6105 - val_precision: 0.5969 - val_recall: 0.6809 - val_auc: 0.6480
# Epoch 172/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6567 - tp: 130558.0000 - fp: 88737.0000 - tn: 111263.0000 - fn: 69442.0000 - accuracy: 0.6046 - precision: 0.5954 - recall: 0.6528 - auc: 0.6495 - val_loss: 0.6584 - val_tp: 13025.0000 - val_fp: 8806.0000 - val_tn: 11194.0000 - val_fn: 6975.0000 - val_accuracy: 0.6055 - val_precision: 0.5966 - val_recall: 0.6513 - val_auc: 0.6466
# Epoch 173/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6568 - tp: 131096.0000 - fp: 89173.0000 - tn: 110827.0000 - fn: 68904.0000 - accuracy: 0.6048 - precision: 0.5952 - recall: 0.6555 - auc: 0.6492 - val_loss: 0.6576 - val_tp: 13241.0000 - val_fp: 8891.0000 - val_tn: 11109.0000 - val_fn: 6759.0000 - val_accuracy: 0.6087 - val_precision: 0.5983 - val_recall: 0.6621 - val_auc: 0.6473
# Epoch 174/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6565 - tp: 130715.0000 - fp: 88509.0000 - tn: 111491.0000 - fn: 69285.0000 - accuracy: 0.6055 - precision: 0.5963 - recall: 0.6536 - auc: 0.6499 - val_loss: 0.6583 - val_tp: 13155.0000 - val_fp: 8779.0000 - val_tn: 11221.0000 - val_fn: 6845.0000 - val_accuracy: 0.6094 - val_precision: 0.5998 - val_recall: 0.6578 - val_auc: 0.6479
# Epoch 175/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6565 - tp: 131050.0000 - fp: 89184.0000 - tn: 110816.0000 - fn: 68950.0000 - accuracy: 0.6047 - precision: 0.5950 - recall: 0.6553 - auc: 0.6495 - val_loss: 0.6589 - val_tp: 13339.0000 - val_fp: 8964.0000 - val_tn: 11036.0000 - val_fn: 6661.0000 - val_accuracy: 0.6094 - val_precision: 0.5981 - val_recall: 0.6669 - val_auc: 0.6463
# Epoch 176/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6567 - tp: 131211.0000 - fp: 89257.0000 - tn: 110743.0000 - fn: 68789.0000 - accuracy: 0.6049 - precision: 0.5951 - recall: 0.6561 - auc: 0.6494 - val_loss: 0.6589 - val_tp: 13215.0000 - val_fp: 8655.0000 - val_tn: 11345.0000 - val_fn: 6785.0000 - val_accuracy: 0.6140 - val_precision: 0.6043 - val_recall: 0.6607 - val_auc: 0.6465
# Epoch 177/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6566 - tp: 130558.0000 - fp: 88670.0000 - tn: 111330.0000 - fn: 69442.0000 - accuracy: 0.6047 - precision: 0.5955 - recall: 0.6528 - auc: 0.6494 - val_loss: 0.6581 - val_tp: 13371.0000 - val_fp: 8953.0000 - val_tn: 11047.0000 - val_fn: 6629.0000 - val_accuracy: 0.6105 - val_precision: 0.5990 - val_recall: 0.6686 - val_auc: 0.6477
# Epoch 178/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6567 - tp: 130925.0000 - fp: 89304.0000 - tn: 110696.0000 - fn: 69075.0000 - accuracy: 0.6041 - precision: 0.5945 - recall: 0.6546 - auc: 0.6490 - val_loss: 0.6592 - val_tp: 13748.0000 - val_fp: 9248.0000 - val_tn: 10752.0000 - val_fn: 6252.0000 - val_accuracy: 0.6125 - val_precision: 0.5978 - val_recall: 0.6874 - val_auc: 0.6467
# Epoch 179/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6568 - tp: 131087.0000 - fp: 89288.0000 - tn: 110712.0000 - fn: 68913.0000 - accuracy: 0.6045 - precision: 0.5948 - recall: 0.6554 - auc: 0.6490 - val_loss: 0.6585 - val_tp: 13571.0000 - val_fp: 9134.0000 - val_tn: 10866.0000 - val_fn: 6429.0000 - val_accuracy: 0.6109 - val_precision: 0.5977 - val_recall: 0.6786 - val_auc: 0.6467
# Epoch 180/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6563 - tp: 130992.0000 - fp: 88689.0000 - tn: 111311.0000 - fn: 69008.0000 - accuracy: 0.6058 - precision: 0.5963 - recall: 0.6550 - auc: 0.6503 - val_loss: 0.6583 - val_tp: 13327.0000 - val_fp: 8982.0000 - val_tn: 11018.0000 - val_fn: 6673.0000 - val_accuracy: 0.6086 - val_precision: 0.5974 - val_recall: 0.6664 - val_auc: 0.6470
# Epoch 181/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6566 - tp: 131208.0000 - fp: 88951.0000 - tn: 111049.0000 - fn: 68792.0000 - accuracy: 0.6056 - precision: 0.5960 - recall: 0.6560 - auc: 0.6493 - val_loss: 0.6581 - val_tp: 13651.0000 - val_fp: 9119.0000 - val_tn: 10881.0000 - val_fn: 6349.0000 - val_accuracy: 0.6133 - val_precision: 0.5995 - val_recall: 0.6826 - val_auc: 0.6480
# Epoch 182/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6562 - tp: 130229.0000 - fp: 88017.0000 - tn: 111983.0000 - fn: 69771.0000 - accuracy: 0.6055 - precision: 0.5967 - recall: 0.6511 - auc: 0.6503 - val_loss: 0.6583 - val_tp: 13597.0000 - val_fp: 9097.0000 - val_tn: 10903.0000 - val_fn: 6403.0000 - val_accuracy: 0.6125 - val_precision: 0.5991 - val_recall: 0.6798 - val_auc: 0.6471
# Epoch 183/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6567 - tp: 130114.0000 - fp: 88176.0000 - tn: 111824.0000 - fn: 69886.0000 - accuracy: 0.6048 - precision: 0.5961 - recall: 0.6506 - auc: 0.6492 - val_loss: 0.6581 - val_tp: 13593.0000 - val_fp: 9127.0000 - val_tn: 10873.0000 - val_fn: 6407.0000 - val_accuracy: 0.6116 - val_precision: 0.5983 - val_recall: 0.6797 - val_auc: 0.6480
# Epoch 184/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6568 - tp: 130420.0000 - fp: 88335.0000 - tn: 111665.0000 - fn: 69580.0000 - accuracy: 0.6052 - precision: 0.5962 - recall: 0.6521 - auc: 0.6494 - val_loss: 0.6585 - val_tp: 13868.0000 - val_fp: 9435.0000 - val_tn: 10565.0000 - val_fn: 6132.0000 - val_accuracy: 0.6108 - val_precision: 0.5951 - val_recall: 0.6934 - val_auc: 0.6465
# Epoch 185/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6565 - tp: 131483.0000 - fp: 89343.0000 - tn: 110657.0000 - fn: 68517.0000 - accuracy: 0.6054 - precision: 0.5954 - recall: 0.6574 - auc: 0.6497 - val_loss: 0.6594 - val_tp: 13015.0000 - val_fp: 8618.0000 - val_tn: 11382.0000 - val_fn: 6985.0000 - val_accuracy: 0.6099 - val_precision: 0.6016 - val_recall: 0.6507 - val_auc: 0.6462
# Epoch 186/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6565 - tp: 130308.0000 - fp: 88432.0000 - tn: 111568.0000 - fn: 69692.0000 - accuracy: 0.6047 - precision: 0.5957 - recall: 0.6515 - auc: 0.6497 - val_loss: 0.6579 - val_tp: 12977.0000 - val_fp: 8707.0000 - val_tn: 11293.0000 - val_fn: 7023.0000 - val_accuracy: 0.6068 - val_precision: 0.5985 - val_recall: 0.6489 - val_auc: 0.6486
# Epoch 187/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6563 - tp: 130484.0000 - fp: 88643.0000 - tn: 111357.0000 - fn: 69516.0000 - accuracy: 0.6046 - precision: 0.5955 - recall: 0.6524 - auc: 0.6499 - val_loss: 0.6582 - val_tp: 13238.0000 - val_fp: 8851.0000 - val_tn: 11149.0000 - val_fn: 6762.0000 - val_accuracy: 0.6097 - val_precision: 0.5993 - val_recall: 0.6619 - val_auc: 0.6475
# Epoch 188/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6565 - tp: 131206.0000 - fp: 89272.0000 - tn: 110728.0000 - fn: 68794.0000 - accuracy: 0.6048 - precision: 0.5951 - recall: 0.6560 - auc: 0.6494 - val_loss: 0.6585 - val_tp: 13548.0000 - val_fp: 9078.0000 - val_tn: 10922.0000 - val_fn: 6452.0000 - val_accuracy: 0.6118 - val_precision: 0.5988 - val_recall: 0.6774 - val_auc: 0.6475
# Epoch 189/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6563 - tp: 130505.0000 - fp: 88450.0000 - tn: 111550.0000 - fn: 69495.0000 - accuracy: 0.6051 - precision: 0.5960 - recall: 0.6525 - auc: 0.6499 - val_loss: 0.6582 - val_tp: 13071.0000 - val_fp: 8700.0000 - val_tn: 11300.0000 - val_fn: 6929.0000 - val_accuracy: 0.6093 - val_precision: 0.6004 - val_recall: 0.6536 - val_auc: 0.6481
# Epoch 190/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6564 - tp: 130814.0000 - fp: 88696.0000 - tn: 111304.0000 - fn: 69186.0000 - accuracy: 0.6053 - precision: 0.5959 - recall: 0.6541 - auc: 0.6498 - val_loss: 0.6584 - val_tp: 13856.0000 - val_fp: 9377.0000 - val_tn: 10623.0000 - val_fn: 6144.0000 - val_accuracy: 0.6120 - val_precision: 0.5964 - val_recall: 0.6928 - val_auc: 0.6471
# Epoch 191/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6567 - tp: 130674.0000 - fp: 88530.0000 - tn: 111470.0000 - fn: 69326.0000 - accuracy: 0.6054 - precision: 0.5961 - recall: 0.6534 - auc: 0.6496 - val_loss: 0.6581 - val_tp: 13453.0000 - val_fp: 9038.0000 - val_tn: 10962.0000 - val_fn: 6547.0000 - val_accuracy: 0.6104 - val_precision: 0.5982 - val_recall: 0.6726 - val_auc: 0.6472
# Epoch 192/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6562 - tp: 131329.0000 - fp: 88913.0000 - tn: 111087.0000 - fn: 68671.0000 - accuracy: 0.6060 - precision: 0.5963 - recall: 0.6566 - auc: 0.6502 - val_loss: 0.6589 - val_tp: 13379.0000 - val_fp: 8919.0000 - val_tn: 11081.0000 - val_fn: 6621.0000 - val_accuracy: 0.6115 - val_precision: 0.6000 - val_recall: 0.6690 - val_auc: 0.6468
# Epoch 193/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6562 - tp: 130618.0000 - fp: 88639.0000 - tn: 111361.0000 - fn: 69382.0000 - accuracy: 0.6049 - precision: 0.5957 - recall: 0.6531 - auc: 0.6503 - val_loss: 0.6589 - val_tp: 13095.0000 - val_fp: 8599.0000 - val_tn: 11401.0000 - val_fn: 6905.0000 - val_accuracy: 0.6124 - val_precision: 0.6036 - val_recall: 0.6547 - val_auc: 0.6475
# Epoch 194/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6561 - tp: 130140.0000 - fp: 87653.0000 - tn: 112347.0000 - fn: 69860.0000 - accuracy: 0.6062 - precision: 0.5975 - recall: 0.6507 - auc: 0.6506 - val_loss: 0.6581 - val_tp: 13267.0000 - val_fp: 8871.0000 - val_tn: 11129.0000 - val_fn: 6733.0000 - val_accuracy: 0.6099 - val_precision: 0.5993 - val_recall: 0.6633 - val_auc: 0.6480
# Epoch 195/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6560 - tp: 131408.0000 - fp: 88812.0000 - tn: 111188.0000 - fn: 68592.0000 - accuracy: 0.6065 - precision: 0.5967 - recall: 0.6570 - auc: 0.6506 - val_loss: 0.6578 - val_tp: 13597.0000 - val_fp: 9249.0000 - val_tn: 10751.0000 - val_fn: 6403.0000 - val_accuracy: 0.6087 - val_precision: 0.5952 - val_recall: 0.6798 - val_auc: 0.6482
# Epoch 196/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6562 - tp: 130625.0000 - fp: 88732.0000 - tn: 111268.0000 - fn: 69375.0000 - accuracy: 0.6047 - precision: 0.5955 - recall: 0.6531 - auc: 0.6501 - val_loss: 0.6581 - val_tp: 13096.0000 - val_fp: 8854.0000 - val_tn: 11146.0000 - val_fn: 6904.0000 - val_accuracy: 0.6061 - val_precision: 0.5966 - val_recall: 0.6548 - val_auc: 0.6486
# Epoch 197/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6562 - tp: 131961.0000 - fp: 89789.0000 - tn: 110211.0000 - fn: 68039.0000 - accuracy: 0.6054 - precision: 0.5951 - recall: 0.6598 - auc: 0.6503 - val_loss: 0.6586 - val_tp: 13066.0000 - val_fp: 8674.0000 - val_tn: 11326.0000 - val_fn: 6934.0000 - val_accuracy: 0.6098 - val_precision: 0.6010 - val_recall: 0.6533 - val_auc: 0.6476
# Epoch 198/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6563 - tp: 130826.0000 - fp: 88585.0000 - tn: 111415.0000 - fn: 69174.0000 - accuracy: 0.6056 - precision: 0.5963 - recall: 0.6541 - auc: 0.6503 - val_loss: 0.6587 - val_tp: 13049.0000 - val_fp: 8788.0000 - val_tn: 11212.0000 - val_fn: 6951.0000 - val_accuracy: 0.6065 - val_precision: 0.5976 - val_recall: 0.6525 - val_auc: 0.6476
# Epoch 199/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6561 - tp: 131021.0000 - fp: 88803.0000 - tn: 111197.0000 - fn: 68979.0000 - accuracy: 0.6055 - precision: 0.5960 - recall: 0.6551 - auc: 0.6504 - val_loss: 0.6586 - val_tp: 13449.0000 - val_fp: 9087.0000 - val_tn: 10913.0000 - val_fn: 6551.0000 - val_accuracy: 0.6090 - val_precision: 0.5968 - val_recall: 0.6725 - val_auc: 0.6471
# Epoch 200/200
# 400000/400000 [==============================] - 1s 3us/sample - loss: 0.6562 - tp: 130875.0000 - fp: 88790.0000 - tn: 111210.0000 - fn: 69125.0000 - accuracy: 0.6052 - precision: 0.5958 - recall: 0.6544 - auc: 0.6502 - val_loss: 0.6579 - val_tp: 13639.0000 - val_fp: 9296.0000 - val_tn: 10704.0000 - val_fn: 6361.0000 - val_accuracy: 0.6086 - val_precision: 0.5947 - val_recall: 0.6819 - val_auc: 0.6478

# %%
plot_metrics(baseline_history)

# %%
val=pd.concat([X_val,y_val],axis=1)
val[b'MLscore']=model.predict(val[features_train[:]], batch_size=10000)
midsig=[]
m1=1100
m2=1075
for cut in np.arange(0, 1.05,0.05):
        midsig.append(significance(val,m1,m2,cut,sigtag=b'sigtag',score=b'MLscore'))
figmidsig=plt.figure(figsize=(16,10))
axmidsig = figmidsig.add_subplot(111)
axmidsig.plot(np.arange(0, 1.05,0.05),midsig)
axmidsig.set_title("significance change with cut--bin"+str(i)+" ht "+str(selections[i][0][0])
                       +"-"+str(selections[i][0][1])+" njet "+str(selections[i][1][0])+"-"+str(selections[i][1][0]-1)
                       +" nbjet "+str(selections[i][2][0])+"-"+str(selections[i][2][1]),fontsize=18)
axmidsig.set_xlabel('Score cut',fontsize=18)
axmidsig.set_ylabel('approximate median significance',fontsize=18)
figscore = plt.figure(figsize=(20,10))
axscore = figscore.add_subplot(111)
bkgscore=[val[(val[b'bkgtype']==0)|(val[b'bkgtype']==1)][b'MLscore'], \
         val[val[b'bkgtype']==2][b'MLscore'],
         val[val[b'bkgtype']==3][b'MLscore']]
bkgweight=[val[(val[b'bkgtype']==0)|(val[b'bkgtype']==1)][b'evt_scale1fb'], \
         val[val[b'bkgtype']==2][b'evt_scale1fb'],
         val[val[b'bkgtype']==3][b'evt_scale1fb']]
bkgname=['top','wjets','zinv']
axscore.hist(bkgscore,bins=np.arange(0,1.025,0.025),stacked=True,alpha=0.5,label=bkgname,density=True,weights=bkgweight)
axscore.hist(val[val[b'sigtag']==1][b'MLscore'],bins=np.arange(0,1.025,0.025),alpha=1,label='signal',density=True,histtype='step',linewidth=2)
axscore.legend(loc='upper left',prop={'size': 12})
axscore.set_title("T1bbbb 2016 score distribution of signal and background for validation set--bin"+str(i)+" ht "+str(selections[i][0][0])
                       +"-"+str(selections[i][0][1])+" njet "+str(selections[i][1][0])+"-"+str(selections[i][1][0]-1)
                       +" nbjet "+str(selections[i][2][0])+"-"+str(selections[i][2][1]),fontsize=20)
axscore.set_xlabel('Score',fontsize=18)
axscore.set_ylabel('fraction',fontsize=18)
# Out:
# WARNING:tensorflow:Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>
# Text(0, 0.5, 'fraction')

# %%
midsig
# Out:
# [0.30100817652254547,
#  0.30100817652254547,
#  0.30100817652254547,
#  0.30204921045746436,
#  0.30544357836585584,
#  0.30534091763918203,
#  0.3055712518680808,
#  0.3185072201298892,
#  0.3100731304019061,
#  0.2916979338652059,
#  0.26260649664462693,
#  0.16780855870744427,
#  0.10929812259675042,
#  0.05560681563495044,
#  0.0457862428784367,
#  0.0,
#  -1,
#  -1,
#  -1,
#  -1,
#  -1]

# %%
for i in [0]:
    m1=2000
    m2=1600
    X=data_input[i][(features_train+[b'evt_scale1fb',b'GenSusyMScan1',b'GenSusyMScan2',b'absweight',b'bkgtype'])[:]]
    y=data_input[i][b'sigtag']
    X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.1, random_state=42)
    X_train=X_train.reset_index(drop=True)
    y_train=y_train.reset_index(drop=True)
    X_val=X_val.reset_index(drop=True)
    y_val=y_val.reset_index(drop=True)
    print (y_train[y_train==0].size, y_train[y_train==1].size, y_val[y_val==0].size, y_val[y_val==1].size)
    val=pd.concat([X_val,y_val],axis=1)
    model = Sequential()
    adam=optimizers.Adam(lr=0.001)
    pos=y[y==1].size
    neg=y[y==0].size
    total=pos+neg
    weight_for_0 = (1 / neg)*(total)/2.0 
    weight_for_1 = (1 / pos)*(total)/2.0
    class_weight = {0: weight_for_0, 1: weight_for_1}
    output_bias = initializers.Constant(np.log([pos/neg]))
    model.add(Dense(128, input_shape=(len(features_train),), kernel_initializer='normal', activation='relu'))
    model.add(Dense(128, kernel_initializer='normal', activation='sigmoid'))
    model.add(Dense(64, kernel_initializer='normal', activation='sigmoid'))
    model.add(Dense(10, kernel_initializer='normal', activation='sigmoid'))
#model.add(Dense(10, kernel_initializer='normal', activation='sigmoid'))
    model.add(Dense(1, kernel_initializer='normal', activation='sigmoid',bias_initializer=output_bias))
    model.compile(optimizer=adam,loss='binary_crossentropy',metrics=METRICS)
    filepath="weights_T1bbbb2016_bin_"+str(i)+".best.hdf5"
    checkpoint = ModelCheckpoint(filepath, monitor='val_auc', verbose=1, save_best_only=True, mode='max')
    callbacks_list = [checkpoint]
    model_history=model.fit(x=X_train[features_train[:]], y=y_train, epochs=100, batch_size=10000,
         validation_data=(X_val[features_train[:]], y_val),callbacks=callbacks_list, verbose=1,class_weight=class_weight)
    figlearn=plot_history([('signal - background classification',model_history)],'loss')
    figlearn.savefig("learningcurve_loss_bin_"+str(i)+".pdf")
    for key in ['tp','fp','tn','fn','accuracy','precision','recall','auc']:
        figlearn=plot_history([('signal - background classification',model_history)],key)
        figlearn.savefig("learningcurve"+key+"_bin_"+str(i)+".pdf")
    model.load_weights(filepath)
    val[b'MLscore']=model.predict(val[features_train[:]], batch_size=10000)
    midsig=[]
    for cut in np.arange(0, 1.05,0.05):
        midsig.append(significance(val,m1,m2,cut,sigtag=b'sigtag',score=b'MLscore'))
    figmidsig=plt.figure(figsize=(16,10))
    axmidsig = figmidsig.add_subplot(111)
    axmidsig.plot(np.arange(0, 1.05,0.05),midsig)
    axmidsig.set_title("significance change with cut--bin"+str(i)+" ht "+str(selections[i][0][0])
                       +"-"+str(selections[i][0][1])+" njet "+str(selections[i][1][0])+"-"+str(selections[i][1][0]-1)
                       +" nbjet "+str(selections[i][2][0])+"-"+str(selections[i][2][1]),fontsize=18)
    axmidsig.set_xlabel('Score cut',fontsize=18)
    axmidsig.set_ylabel('approximate median significance',fontsize=18)
    figscore = plt.figure(figsize=(20,10))
    axscore = figscore.add_subplot(111)
    bkgscore=[val[(val[b'bkgtype']==0)|(val[b'bkgtype']==1)][b'MLscore'], \
         val[val[b'bkgtype']==2][b'MLscore'],
         val[val[b'bkgtype']==3][b'MLscore']]
    bkgweight=[val[(val[b'bkgtype']==0)|(val[b'bkgtype']==1)][b'evt_scale1fb'], \
         val[val[b'bkgtype']==2][b'evt_scale1fb'],
         val[val[b'bkgtype']==3][b'evt_scale1fb']]
    bkgname=['top','wjets','zinv']
    axscore.hist(bkgscore,bins=np.arange(0,1.025,0.025),stacked=True,alpha=0.5,label=bkgname,density=True,weights=bkgweight)
    axscore.hist(val[val[b'sigtag']==1][b'MLscore'],bins=np.arange(0,1.025,0.025),alpha=1,label='signal '+str(m1)+" "+str(m2),density=True,histtype='step',linewidth=2)
    axscore.legend(loc='upper left',prop={'size': 12})
    axscore.set_title("T1bbbb 2016 score distribution of signal and background for validation set--bin"+str(i)+" ht "+str(selections[i][0][0])
                       +"-"+str(selections[i][0][1])+" njet "+str(selections[i][1][0])+"-"+str(selections[i][1][0]-1)
                       +" nbjet "+str(selections[i][2][0])+"-"+str(selections[i][2][1]),fontsize=20)
    axscore.set_xlabel('Score',fontsize=18)
    axscore.set_ylabel('fraction',fontsize=18)
#X=X.fillna(0,inplace=True)

# %%
weight_for_1

# %%
#model.fit(x=X_train[features_train[:]], y=y_train, epochs=10, batch_size=10000)

# %%
model1 = Sequential()
adam=optimizers.Adam(lr=0.001)
model1.add(Dense(1024, input_shape=(X[features_train].shape[1],), kernel_initializer='normal', activation='relu'))
model1.add(Dense(500, kernel_initializer='normal', activation='sigmoid'))
model1.add(Dense(128, kernel_initializer='normal', activation='sigmoid'))
model1.add(Dense(64, kernel_initializer='normal', activation='sigmoid'))
model1.add(Dense(64, kernel_initializer='normal', activation='sigmoid'))
#model.add(Dense(10, kernel_initializer='normal', activation='sigmoid'))
model1.add(Dense(1, kernel_initializer='normal', activation='sigmoid'))
model1.compile(optimizer=adam,loss='binary_crossentropy',metrics=['accuracy'])
model1.load_weights("weights_T1bbbb2016_unweighted_btagDeepCSV_excluded_V02.best.hdf5")
#model1.load_weights("weights_T1bbbb2016_unweighted_V02.best.hdf5")
#model1.load_weights("weights_T1bbbb2016_unweighted.best.hdf5")
#model1.load_weights("weights_T1bbbb2016_unweighted_btagDeepCSV_excluded.best.hdf5")

# %%
#model1.save("model_T1bbbb2016_unweighted_btagDeepCSV_excluded.h5")
#model1.save("model_T1bbbb2016_unweighted.h5")
#model1.save("model_T1bbbb2016_unweighted_V02.h5")
model1.save("model_T1bbbb2016_unweighted_btagDeepCSV_excluded_V02.h5")

# %%
fig=plot_history([('signal - background classification',model_history)])
#fig.savefig('T1bbbb_unweighted_learningcurve_V02.pdf')
#fig.savefig('T1bbbb_unweighted_learningcurve_V02.png')
#fig.savefig('T1bbbb_unweighted_learningcurve_btagDeepCSVexcluded.pdf')
#fig.savefig('T1bbbb_unweighted_learningcurve_btagDeepCSVexcluded.png')
fig.savefig('T1bbbb_unweighted_learningcurve_btagDeepCSVexcluded_V02.pdf')
fig.savefig('T1bbbb_unweighted_learningcurve_btagDeepCSVexcluded_V02.png')

# %%
results = model1.predict(X_val[features_train[:]], batch_size=10000)

# %%
from sklearn.metrics import roc_auc_score
auc = roc_auc_score(y_val, results,sample_weight=X_val[b'evt_scale1fb'][:])
#auc = roc_auc_score(y_test, results)
print("area under ROC curve: ", auc)

# %%
sigtest_score= model1.predict(datasig_T1bbbb_2016_test[features_train[:]], batch_size=10000)
bkgtest_score= model1.predict(databkg_2016_test[features_train[:]],batch_size=10000)

# %%
databkg_2016_test[b'MLscore']=bkgtest_score
datasig_T1bbbb_2016_test[b'MLscore']=sigtest_score

# %%
fig3 = plt.figure(figsize=(20,10))
ax3 = fig3.add_subplot(111)
bkgscore=[databkg_2016_test[databkg_2016_test[b'bkgtype']==0][b'MLscore'], \
          databkg_2016_test[(databkg_2016_test[b'bkgtype']==1)|(databkg_2016_test[b'bkgtype']==2)][b'MLscore'], \
         databkg_2016_test[databkg_2016_test[b'bkgtype']==3][b'MLscore'],
         databkg_2016_test[databkg_2016_test[b'bkgtype']==4][b'MLscore']]
bkgweight=[databkg_2016_test[databkg_2016_test[b'bkgtype']==0][b'evt_scale1fb'], \
          databkg_2016_test[(databkg_2016_test[b'bkgtype']==1)|(databkg_2016_test[b'bkgtype']==2)][b'evt_scale1fb'], \
         databkg_2016_test[databkg_2016_test[b'bkgtype']==3][b'evt_scale1fb'],
         databkg_2016_test[databkg_2016_test[b'bkgtype']==4][b'evt_scale1fb']]
bkgname=['qcd','top','wjets','zinv']
ax3.hist(bkgscore,bins=np.arange(0,1.025,0.025),stacked=True,alpha=0.5,label=bkgname,density=True,weights=bkgweight)
ax3.hist(datasig_T1bbbb_2016_test[b'MLscore'],bins=np.arange(0,1.025,0.025),alpha=1,label='score of test: signal',density=True,histtype='step',linewidth=2)
ax3.legend(loc='upper left',prop={'size': 12})
ax3.set_title("T1bbbb 2016 score distribution of signal and background for testing set",fontsize=20)
ax3.set_xlabel('Score',fontsize=18)
ax3.set_ylabel('fraction',fontsize=18)
#fig3.savefig('T1bbbb_2016_scoredistribution_V02.pdf')
#fig3.savefig('T1bbbb_2016_scoredistribution_V02.png')
#fig3.savefig('T1bbbb_2016_scoredistribution.pdf')
#fig3.savefig('T1bbbb_2016_scoredistribution.png')
#fig3.savefig('T1bbbb_2016_scoredistribution_btagDeepCSV_excluded.pdf')
#fig3.savefig('T1bbbb_2016_scoredistribution_btagDeepCSV_excluded.png')
fig3.savefig('T1bbbb_2016_scoredistribution_btagDeepCSV_excluded_V02.pdf')
fig3.savefig('T1bbbb_2016_scoredistribution_btagDeepCSV_excluded_V02.png')

# %%
fig1 = plt.figure(figsize=(20,10))
ax0 = fig1.add_subplot(111)
bins=np.histogram(datasig_T1bbbb_2016_test[b'mt2'],bins=30)[1]
labels=['mt2 of signal T1bbbb before cut','mt2 of signal T1bbbb after cut']
ax0.hist(datasig_T1bbbb_2016_test[b'mt2'],
             bins=bins,density=True,alpha=0.5,color='orange',
             label=labels[0])
ax0.hist(datasig_T1bbbb_2016_test[datasig_T1bbbb_2016_test[b'MLscore']>0.5][b'mt2'],
             bins=bins,density=True,color='b',histtype='step',
             label=labels[1])
ax0.legend(loc='best',prop={'size': 12})
ax0.set_yscale('log')
ax0.set_xlabel('mt2',fontsize=18)
ax0.set_ylabel('fraction',fontsize=18)
ax0.set_title('comparison of T1bbbb signal before and after cut',size=20)
fig1.show()

# %%
fig2 = plt.figure(figsize=(20,10))
ax2 = fig2.add_subplot(111)
bins=np.histogram(databkg_2016_test[b'mt2'],bins=30)[1]
labels=['mt2 of accumulated background before cut','mt2 of accululated background after cut']
ax2.hist(databkg_2016_test[b'mt2'],
             bins=bins,density=True,alpha=0.5,color='orange',
         weights=databkg_2016_test[b'evt_scale1fb'],
             label=labels[0])
ax2.hist(databkg_2016_test[databkg_2016_test[b'MLscore']>0.5][b'mt2'],
             bins=bins,density=True,color='b',histtype='step',
         weights=databkg_2016_test[databkg_2016_test[b'MLscore']>0.5][b'evt_scale1fb'],
             label=labels[1])
ax2.legend(loc='best',prop={'size': 12})
ax2.set_yscale('log')
ax2.set_xlabel('mt2',fontsize=18)
ax2.set_ylabel('fraction',fontsize=18)
ax2.set_title('comparison of total background before and after cut',size=20)
fig2.show()

# %%
fig3 = plt.figure(figsize=(20,10))
ax3 = fig3.add_subplot(111)
bins=np.histogram(databkg_2016_test[databkg_2016_test[b'bkgtype']==4][b'mt2'],bins=30)[1]
labels=['mt2 of zinv background before cut','mt2 of zinv background after cut']
ax3.hist(databkg_2016_test[databkg_2016_test[b'bkgtype']==4][b'mt2'],
             bins=bins,density=True,alpha=0.5,color='orange',
         weights=databkg_2016_test[databkg_2016_test[b'bkgtype']==4][b'evt_scale1fb'],
             label=labels[0])
ax3.hist(databkg_2016_test[(databkg_2016_test[b'MLscore']>0.5)&(databkg_2016_test[b'bkgtype']==4)][b'mt2'],
             bins=bins,density=True,color='b',histtype='step',
         weights=databkg_2016_test[(databkg_2016_test[b'MLscore']>0.5)&(databkg_2016_test[b'bkgtype']==4)][b'evt_scale1fb'],
             label=labels[1])
ax3.legend(loc='best',prop={'size': 12})
ax3.set_yscale('log')
ax3.set_xlabel('mt2',fontsize=18)
ax3.set_ylabel('fraction',fontsize=18)
ax3.set_title('comparison of zinv background before and after cut',size=20)
fig3.show()

# %%
fig4 = plt.figure(figsize=(20,10))
ax4 = fig4.add_subplot(111)
bins=np.histogram(databkg_2016_test[databkg_2016_test[b'bkgtype']==3][b'mt2'],bins=30)[1]
labels=['mt2 of wjets background before cut','mt2 of wjets background after cut']
ax4.hist(databkg_2016_test[databkg_2016_test[b'bkgtype']==3][b'mt2'],
             bins=bins,density=True,alpha=0.5,color='orange',
         weights=databkg_2016_test[databkg_2016_test[b'bkgtype']==3][b'evt_scale1fb'],
             label=labels[0])
ax4.hist(databkg_2016_test[(databkg_2016_test[b'MLscore']>0.5)&(databkg_2016_test[b'bkgtype']==3)][b'mt2'],
             bins=bins,density=True,color='b',histtype='step',
         weights=databkg_2016_test[(databkg_2016_test[b'MLscore']>0.5)&(databkg_2016_test[b'bkgtype']==3)][b'evt_scale1fb'],
             label=labels[1])
ax4.legend(loc='best',prop={'size': 12})
ax4.set_yscale('log')
ax4.set_xlabel('mt2',fontsize=18)
ax4.set_ylabel('fraction',fontsize=18)
ax4.set_title('comparison of wjets background before and after cut',size=20)
fig4.show()

# %%
fig5 = plt.figure(figsize=(20,10))
ax5 = fig5.add_subplot(111)
bins=np.histogram(databkg_2016_test[databkg_2016_test[b'bkgtype']==0][b'mt2'],bins=30)[1]
labels=['mt2 of singletop background before cut','mt2 of singletop background after cut']
ax5.hist(databkg_2016_test[databkg_2016_test[b'bkgtype']==0][b'mt2'],
             bins=bins,density=True,alpha=0.5,color='orange',
         weights=databkg_2016_test[databkg_2016_test[b'bkgtype']==0][b'evt_scale1fb'],
             label=labels[0])
ax5.hist(databkg_2016_test[(databkg_2016_test[b'MLscore']>0.5)&(databkg_2016_test[b'bkgtype']==0)][b'mt2'],
             bins=bins,density=True,color='b',histtype='step',
         weights=databkg_2016_test[(databkg_2016_test[b'MLscore']>0.5)&(databkg_2016_test[b'bkgtype']==0)][b'evt_scale1fb'],
             label=labels[1])
ax5.legend(loc='best',prop={'size': 12})
ax5.set_yscale('log')
ax5.set_xlabel('mt2',fontsize=18)
ax5.set_ylabel('fraction',fontsize=18)
ax5.set_title('comparison of qcd background before and after cut',size=20)
fig5.show()

# %%
fig7 = plt.figure(figsize=(20,10))
ax7 = fig7.add_subplot(111)
bins=np.histogram(databkg_2016_test[(databkg_2016_test[b'bkgtype']==1)|(databkg_2016_test[b'bkgtype']==2)][b'mt2'],bins=30)[1]
labels=['mt2 of top background before cut','mt2 of top background after cut']
ax7.hist(databkg_2016_test[(databkg_2016_test[b'bkgtype']==1)|(databkg_2016_test[b'bkgtype']==2)][b'mt2'],
             bins=bins,density=True,alpha=0.5,color='orange',
         weights=databkg_2016_test[(databkg_2016_test[b'bkgtype']==1)|(databkg_2016_test[b'bkgtype']==2)][b'evt_scale1fb'],
             label=labels[0])
ax7.hist(databkg_2016_test[(databkg_2016_test[b'MLscore']>0.5)&((databkg_2016_test[b'bkgtype']==1)|(databkg_2016_test[b'bkgtype']==2))][b'mt2'],
             bins=bins,density=True,color='b',histtype='step',
         weights=databkg_2016_test[(databkg_2016_test[b'MLscore']>0.5)&((databkg_2016_test[b'bkgtype']==1)|(databkg_2016_test[b'bkgtype']==2))][b'evt_scale1fb'],
             label=labels[1])
ax7.legend(loc='best',prop={'size': 12})
ax7.set_yscale('log')
ax7.set_xlabel('mt2',fontsize=18)
ax7.set_ylabel('fraction',fontsize=18)
ax7.set_title('comparison of top background before and after cut',size=20)
fig7.show()

# %%
databkg_2016_test=databkg_2016[databkg_2016[b'MLtag']!=1]
datasig_T1bbbb_2016_test=datasig_T1bbbb_2016[datasig_T1bbbb_2016[b'MLtag']!=1]
pd.options.mode.chained_assignment = None
databkg_2016_test[b'sigtag']=0
datasig_T1bbbb_2016_test[b'sigtag']=1
