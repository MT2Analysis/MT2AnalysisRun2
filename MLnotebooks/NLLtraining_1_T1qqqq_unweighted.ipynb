# %%
import tensorflow as tf
import numpy as np
import pandas as pd
from keras.layers import Dense
from keras.models import Sequential
from keras.losses import binary_crossentropy
import seaborn
import matplotlib.pyplot as plt
from keras import optimizers
from keras.callbacks import ModelCheckpoint
# Out:
# Using TensorFlow backend.

# %%
bkgfiles_2016=[#'/scratch/wjin/featurereduced3/bkg/preselection_2016_dyjetsll_slim.npy',
#'/scratch/wjin/featurereduced3/bkg/preselection_2016_gjets_slim.npy',
'/work/wjin/featurereduced4/bkg/preselection_2016_qcd_skim.npy',
'/work/wjin/featurereduced4/bkg/preselection_2016_singletop_skim.npy',
'/work/wjin/featurereduced4/bkg/preselection_2016_tt_skim.npy',
#'/scratch/wjin/featurereduced3/bkg/preselection_2016_tt_negligible_slim.npy',
'/work/wjin/featurereduced4/bkg/preselection_2016_wjets_skim.npy',
#'/scratch/wjin/featurereduced3/bkg/preselection_2016_ww_wz_slim.npy',
'/work/wjin/featurereduced4/bkg/preselection_2016_zinv_skim.npy']

bkgfiles_2017=[#'/scratch/wjin/featurereduced3/bkg/preselection_2017_dyjetsll_slim.npy',
#'/scratch/wjin/featurereduced3/bkg/preselection_2017_gjets_slim.npy',
'/work/wjin/featurereduced4/bkg/preselection_2017_qcd_skim.npy',
'/work/wjin/featurereduced4/bkg/preselection_2017_singletop_skim.npy',
'/work/wjin/featurereduced4/bkg/preselection_2017_tt_skim.npy',
#'/scratch/wjin/featurereduced3/bkg/preselection_2017_tt_negligible_slim.npy',
'/work/wjin/featurereduced4/bkg/preselection_2017_wjets_skim.npy',
#'/scratch/wjin/featurereduced3/bkg/preselection_2017_ww_wz_slim.npy',
'/work/wjin/featurereduced4/bkg/preselection_2017_zinv_skim.npy']

bkgfiles_2018=[#'/scratch/wjin/featurereduced3/bkg/preselection_2018_dyjetsll_slim.npy',
#'/scratch/wjin/featurereduced3/bkg/preselection_2018_gjets_slim.npy',
'/work/wjin/featurereduced4/bkg/preselection_2018_qcd_skim.npy',
'/work/wjin/featurereduced4/bkg/preselection_2018_singletop_skim.npy',
'/work/wjin/featurereduced4/bkg/preselection_2018_tt_skim.npy',
#'/scratch/wjin/featurereduced3/bkg/preselection_2018_tt_negligible_slim.npy',
'/work/wjin/featurereduced4/bkg/preselection_2018_wjets_skim.npy',
#'/scratch/wjin/featurereduced3/bkg/preselection_2018_ww_wz_slim.npy',
'/work/wjin/featurereduced4/bkg/preselection_2018_zinv_skim.npy']

sigfiles_T1qqqq_2016=['/work/wjin/featurereduced4/sig/preselection_2016_T1qqqq_94x_1_skim.npy',
                     '/work/wjin/featurereduced4/sig/preselection_2016_T1qqqq_94x_2_skim.npy',
                     '/work/wjin/featurereduced4/sig/preselection_2016_T1qqqq_94x_skim.npy']

sigfiles_T1qqqq_2017=['/work/wjin/featurereduced4/sig/preselection_2017_T1qqqq_1_skim.npy',
                     '/work/wjin/featurereduced4/sig/preselection_2017_T1qqqq_2_skim.npy',
                     '/work/wjin/featurereduced4/sig/preselection_2017_T1qqqq_ext1_1_skim.npy',
                     '/work/wjin/featurereduced4/sig/preselection_2017_T1qqqq_ext1_2_skim.npy',
                     '/work/wjin/featurereduced4/sig/preselection_2017_T1qqqq_ext1_3_skim.npy',
                     '/work/wjin/featurereduced4/sig/preselection_2017_T1qqqq_ext1_4_skim.npy',
                     '/work/wjin/featurereduced4/sig/preselection_2017_T1qqqq_ext1_skim.npy',
                     '/work/wjin/featurereduced4/sig/preselection_2017_T1qqqq_skim.npy']

# %%
databkg_2016=[]
for i in range(5):
    databkg_2016.append(pd.DataFrame(np.load(bkgfiles_2016[i]).item()))
    databkg_2016[i][b'bkgtype']=i
databkg_2016=pd.concat(databkg_2016,axis=0)

# %%
#databkg_2016=pd.concat([pd.DataFrame(np.load(i).item()) for i in bkgfiles_2016],axis=0)
#datasig_T1bbbb_2016=pd.concat([pd.DataFrame(np.load(i).item()) for i in sigfiles_T1bbbb_2016],axis=0)

# %%
datasig_T1qqqq_2016=pd.concat([pd.DataFrame(np.load(i).item()) for i in sigfiles_T1qqqq_2016],axis=0)
datasig_T1qqqq_2016[b'bkgtype']=-1

# %%
databkg_2016 = databkg_2016.replace(np.nan, 0)
datasig_T1qqqq_2016= datasig_T1qqqq_2016.replace(np.nan,0)

# %%
databkg_2016[b'evt_scale1fb'] = databkg_2016[b'evt_scale1fb'].abs()

# %%
#np.random.seed(123)
#databkg_2016[b'MLtag']=np.random.randint(0,10,databkg_2016.shape[0])
#datasig_T1qqqq_2016[b'MLtag']=np.random.randint(0,10,datasig_T1qqqq_2016.shape[0])

# %%
databkg_2016_ML=databkg_2016[databkg_2016[b'MLtag']==1]
datasig_T1qqqq_2016_ML=datasig_T1qqqq_2016[datasig_T1qqqq_2016[b'MLtag']==1]

# %%
databkg_2016_test=databkg_2016[databkg_2016[b'MLtag']!=1]
datasig_T1qqqq_2016_test=datasig_T1qqqq_2016[datasig_T1qqqq_2016[b'MLtag']!=1]
pd.options.mode.chained_assignment = None
databkg_2016_test[b'sigtag']=0
datasig_T1qqqq_2016_test[b'sigtag']=1

# %%
#databkg_2016_try=databkg_2016.sample(frac=0.5,replace=True,random_state=13,axis=0)

# %%
#datasig_T1bbbb_2016_try=datasig_T1bbbb_2016.sample(frac=0.5,replace=True,random_state=13,axis=0)

# %%
pd.options.mode.chained_assignment = None
databkg_2016_ML[b'sigtag']=0
datasig_T1qqqq_2016_ML[b'sigtag']=1

# %%
data_input=pd.concat([databkg_2016_ML,datasig_T1qqqq_2016_ML],axis=0)
data_input=data_input.reset_index(drop=True)
del databkg_2016_ML
del datasig_T1qqqq_2016_ML

# %%
features_exclude=[b'nJet30',b'nJet40',b'nBJet20',b'nBJet30',b'nBJet40',b'ht',b'mt2',b'mht_pt',b'met_pt',b'mht_phi',b'met_phi',b'njet']
#features_train=[b'deltaPhiMin',b'diffMetMht',
#          b'jet1_eta',b'jet1_phi',b'jet1_btagDeepCSV',b'jet2_eta',b'jet2_phi',b'jet2_btagDeepCSV',b'jet3_eta',b'jet3_phi',b'jet3_btagDeepCSV',
 #         b'jet4_eta',b'jet4_phi',b'jet4_btagDeepCSV',b'jet5_eta',b'jet5_phi',b'jet5_btagDeepCSV',b'jet6_eta',b'jet6_phi',b'jet6_btagDeepCSV',
  #        b'jet7_eta',b'jet7_phi',b'jet7_btagDeepCSV',b'jet8_eta',b'jet8_phi',b'jet8_btagDeepCSV',b'jet9_eta',b'jet9_phi',b'jet9_btagDeepCSV',
   #       b'jet10_eta',b'jet10_phi',b'jet10_btagDeepCSV',b'jet11_eta',b'jet11_phi',b'jet11_btagDeepCSV',b'jet12_eta',b'jet12_phi',b'jet12_btagDeepCSV',
    #      b'jet13_eta',b'jet13_phi',b'jet13_btagDeepCSV',b'jet14_eta',b'jet14_phi',b'jet14_btagDeepCSV',b'jet15_eta',b'jet15_phi',b'jet15_btagDeepCSV',
     #     b'jet1_pt',b'jet2_pt',b'jet3_pt',b'jet4_pt',b'jet5_pt',
      #    b'jet6_pt',b'jet7_pt',b'jet8_pt',b'jet9_pt',b'jet10_pt',
       #   b'jet11_pt',b'jet12_pt',b'jet13_pt',b'jet14_pt',b'jet15_pt']

features_train=[b'deltaPhiMin',b'diffMetMht',
           b'jet1_eta',b'jet1_phi',b'jet2_eta',b'jet2_phi',b'jet3_eta',b'jet3_phi',
          b'jet4_eta',b'jet4_phi',b'jet5_eta',b'jet5_phi',b'jet6_eta',b'jet6_phi',
          b'jet7_eta',b'jet7_phi',b'jet8_eta',b'jet8_phi',b'jet9_eta',b'jet9_phi',
          b'jet10_eta',b'jet10_phi',b'jet11_eta',b'jet11_phi',b'jet12_eta',b'jet12_phi',
          b'jet13_eta',b'jet13_phi',b'jet14_eta',b'jet14_phi',b'jet15_eta',b'jet15_phi',
           b'jet1_pt',b'jet2_pt',b'jet3_pt',b'jet4_pt',b'jet5_pt',
              b'jet6_pt',b'jet7_pt',b'jet8_pt',b'jet9_pt',b'jet10_pt',
              b'jet11_pt',b'jet12_pt',b'jet13_pt',b'jet14_pt',b'jet15_pt']

# %%
X=data_input[(features_train+[b'evt_scale1fb'])[:]]
y=data_input[b'sigtag']
#X=X.fillna(0,inplace=True)

# %%
from sklearn.model_selection import train_test_split
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.05, random_state=42)

# %%
X_train=X_train.reset_index(drop=True)
y_train=y_train.reset_index(drop=True)

# %%
X_val=X_val.reset_index(drop=True)
y_val=y_val.reset_index(drop=True)

# %%
X_test

# %%
model = Sequential()
#model.add(Dense(1024, activation="relu", input_shape=(X.shape[1],)))
#model.add(Dense(512, activation="relu"))
#model.add(Dense(512, activation="relu"))
#model.add(Dense(256, activation="relu"))
#model.add(Dense(1))
model.add(Dense(128, input_shape=(X[features_train].shape[1],), kernel_initializer='normal', activation='relu'))
model.add(Dense(64, kernel_initializer='normal', activation='sigmoid'))
model.add(Dense(64, kernel_initializer='normal', activation='sigmoid'))
#model.add(Dense(10, kernel_initializer='normal', activation='sigmoid'))
model.add(Dense(1, kernel_initializer='normal', activation='sigmoid'))
model.compile(optimizer="adam", loss='binary_crossentropy',metrics=['accuracy'])
filepath="weights_T1qqqq2016_unweighted_btagDeepCSV_excluded_V02.best.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max')
callbacks_list = [checkpoint]

# %%
model_history=model.fit(x=X_train[features_train[:]], y=y_train, epochs=100, batch_size=10000,
         validation_data=(X_val[features_train[:]], y_val),callbacks=callbacks_list, verbose=1)
#model.fit(x=X_train[features_train[:]], y=y_train, epochs=10, batch_size=10000)
# Out:
# Train on 563759 samples, validate on 29672 samples
# Epoch 1/100
# 563759/563759 [==============================] - 3s 5us/step - loss: 0.5302 - acc: 0.7628 - val_loss: 0.4614 - val_acc: 0.8007
#
# Epoch 00001: val_acc improved from -inf to 0.80065, saving model to weights_T1qqqq2016_unweighted_btagDeepCSV_excluded_V02.best.hdf5
# Epoch 2/100
# 563759/563759 [==============================] - 2s 3us/step - loss: 0.4190 - acc: 0.7997 - val_loss: 0.3854 - val_acc: 0.8007
#
# Epoch 00002: val_acc did not improve from 0.80065
# Epoch 3/100
# 563759/563759 [==============================] - 2s 3us/step - loss: 0.3692 - acc: 0.8540 - val_loss: 0.3592 - val_acc: 0.8609
#
# Epoch 00003: val_acc improved from 0.80065 to 0.86095, saving model to weights_T1qqqq2016_unweighted_btagDeepCSV_excluded_V02.best.hdf5
# Epoch 4/100
# 563759/563759 [==============================] - 2s 3us/step - loss: 0.3507 - acc: 0.8610 - val_loss: 0.3451 - val_acc: 0.8634
#
# Epoch 00004: val_acc improved from 0.86095 to 0.86344, saving model to weights_T1qqqq2016_unweighted_btagDeepCSV_excluded_V02.best.hdf5
# Epoch 5/100
# 563759/563759 [==============================] - 2s 3us/step - loss: 0.3388 - acc: 0.8632 - val_loss: 0.3384 - val_acc: 0.8618
#
# Epoch 00005: val_acc did not improve from 0.86344
# Epoch 6/100
# 563759/563759 [==============================] - 2s 3us/step - loss: 0.3337 - acc: 0.8632 - val_loss: 0.3342 - val_acc: 0.8630
#
# Epoch 00006: val_acc did not improve from 0.86344
# Epoch 7/100
# 563759/563759 [==============================] - 2s 3us/step - loss: 0.3290 - acc: 0.8643 - val_loss: 0.3298 - val_acc: 0.8635
#
# Epoch 00007: val_acc improved from 0.86344 to 0.86354, saving model to weights_T1qqqq2016_unweighted_btagDeepCSV_excluded_V02.best.hdf5
# Epoch 8/100
# 563759/563759 [==============================] - 2s 3us/step - loss: 0.3265 - acc: 0.8645 - val_loss: 0.3288 - val_acc: 0.8631
#
# Epoch 00008: val_acc did not improve from 0.86354
# Epoch 9/100
# 563759/563759 [==============================] - 2s 3us/step - loss: 0.3250 - acc: 0.8649 - val_loss: 0.3248 - val_acc: 0.8644
#
# Epoch 00009: val_acc improved from 0.86354 to 0.86435, saving model to weights_T1qqqq2016_unweighted_btagDeepCSV_excluded_V02.best.hdf5
# Epoch 10/100
# 563759/563759 [==============================] - 2s 3us/step - loss: 0.3225 - acc: 0.8657 - val_loss: 0.3245 - val_acc: 0.8648
#
# Epoch 00010: val_acc improved from 0.86435 to 0.86482, saving model to weights_T1qqqq2016_unweighted_btagDeepCSV_excluded_V02.best.hdf5
# Epoch 11/100
# 563759/563759 [==============================] - 2s 3us/step - loss: 0.3215 - acc: 0.8658 - val_loss: 0.3222 - val_acc: 0.8652
#
# Epoch 00011: val_acc improved from 0.86482 to 0.86523, saving model to weights_T1qqqq2016_unweighted_btagDeepCSV_excluded_V02.best.hdf5
# Epoch 12/100
# 563759/563759 [==============================] - 2s 3us/step - loss: 0.3194 - acc: 0.8665 - val_loss: 0.3191 - val_acc: 0.8658
#
# Epoch 00012: val_acc improved from 0.86523 to 0.86583, saving model to weights_T1qqqq2016_unweighted_btagDeepCSV_excluded_V02.best.hdf5
# Epoch 13/100
# 563759/563759 [==============================] - 2s 3us/step - loss: 0.3179 - acc: 0.8669 - val_loss: 0.3187 - val_acc: 0.8668
#
# Epoch 00013: val_acc improved from 0.86583 to 0.86684, saving model to weights_T1qqqq2016_unweighted_btagDeepCSV_excluded_V02.best.hdf5
# Epoch 14/100
# 563759/563759 [==============================] - 2s 3us/step - loss: 0.3157 - acc: 0.8681 - val_loss: 0.3225 - val_acc: 0.8650
#
# Epoch 00014: val_acc did not improve from 0.86684
# Epoch 15/100
# 563759/563759 [==============================] - 2s 3us/step - loss: 0.3166 - acc: 0.8672 - val_loss: 0.3161 - val_acc: 0.8680
#
# Epoch 00015: val_acc improved from 0.86684 to 0.86796, saving model to weights_T1qqqq2016_unweighted_btagDeepCSV_excluded_V02.best.hdf5
# Epoch 16/100
# 563759/563759 [==============================] - 2s 3us/step - loss: 0.3131 - acc: 0.8690 - val_loss: 0.3159 - val_acc: 0.8666
#
# Epoch 00016: val_acc did not improve from 0.86796
# Epoch 17/100
# 563759/563759 [==============================] - 2s 3us/step - loss: 0.3149 - acc: 0.8682 - val_loss: 0.3137 - val_acc: 0.8681
#
# Epoch 00017: val_acc improved from 0.86796 to 0.86812, saving model to weights_T1qqqq2016_unweighted_btagDeepCSV_excluded_V02.best.hdf5
# Epoch 18/100
# 563759/563759 [==============================] - 2s 3us/step - loss: 0.3121 - acc: 0.8690 - val_loss: 0.3135 - val_acc: 0.8684
#
# Epoch 00018: val_acc improved from 0.86812 to 0.86839, saving model to weights_T1qqqq2016_unweighted_btagDeepCSV_excluded_V02.best.hdf5
# Epoch 19/100
# 563759/563759 [==============================] - 2s 3us/step - loss: 0.3106 - acc: 0.8698 - val_loss: 0.3162 - val_acc: 0.8676
#
# Epoch 00019: val_acc did not improve from 0.86839
# Epoch 20/100
# 563759/563759 [==============================] - 2s 3us/step - loss: 0.3112 - acc: 0.8695 - val_loss: 0.3123 - val_acc: 0.8690
#
# Epoch 00020: val_acc improved from 0.86839 to 0.86903, saving model to weights_T1qqqq2016_unweighted_btagDeepCSV_excluded_V02.best.hdf5
# Epoch 21/100
# 563759/563759 [==============================] - 2s 3us/step - loss: 0.3094 - acc: 0.8701 - val_loss: 0.3114 - val_acc: 0.8695
#
# Epoch 00021: val_acc improved from 0.86903 to 0.86954, saving model to weights_T1qqqq2016_unweighted_btagDeepCSV_excluded_V02.best.hdf5
# Epoch 22/100
# 563759/563759 [==============================] - 2s 3us/step - loss: 0.3096 - acc: 0.8698 - val_loss: 0.3116 - val_acc: 0.8685
#
# Epoch 00022: val_acc did not improve from 0.86954
# Epoch 23/100
# 563759/563759 [==============================] - 2s 3us/step - loss: 0.3083 - acc: 0.8702 - val_loss: 0.3130 - val_acc: 0.8696
#
# Epoch 00023: val_acc improved from 0.86954 to 0.86961, saving model to weights_T1qqqq2016_unweighted_btagDeepCSV_excluded_V02.best.hdf5
# Epoch 24/100
# 563759/563759 [==============================] - 2s 3us/step - loss: 0.3090 - acc: 0.8700 - val_loss: 0.3092 - val_acc: 0.8696
#
# Epoch 00024: val_acc improved from 0.86961 to 0.86961, saving model to weights_T1qqqq2016_unweighted_btagDeepCSV_excluded_V02.best.hdf5
# Epoch 25/100
# 563759/563759 [==============================] - 2s 3us/step - loss: 0.3071 - acc: 0.8705 - val_loss: 0.3090 - val_acc: 0.8696
#
# Epoch 00025: val_acc improved from 0.86961 to 0.86964, saving model to weights_T1qqqq2016_unweighted_btagDeepCSV_excluded_V02.best.hdf5
# Epoch 26/100
# 563759/563759 [==============================] - 2s 3us/step - loss: 0.3061 - acc: 0.8710 - val_loss: 0.3093 - val_acc: 0.8707
#
# Epoch 00026: val_acc improved from 0.86964 to 0.87069, saving model to weights_T1qqqq2016_unweighted_btagDeepCSV_excluded_V02.best.hdf5
# Epoch 27/100
# 563759/563759 [==============================] - 2s 3us/step - loss: 0.3053 - acc: 0.8714 - val_loss: 0.3076 - val_acc: 0.8693
#
# Epoch 00027: val_acc did not improve from 0.87069
# Epoch 28/100
# 563759/563759 [==============================] - 2s 3us/step - loss: 0.3058 - acc: 0.8712 - val_loss: 0.3070 - val_acc: 0.8698
#
# Epoch 00028: val_acc did not improve from 0.87069
# Epoch 29/100
# 563759/563759 [==============================] - 2s 3us/step - loss: 0.3042 - acc: 0.8716 - val_loss: 0.3070 - val_acc: 0.8697
#
# Epoch 00029: val_acc did not improve from 0.87069
# Epoch 30/100
# 563759/563759 [==============================] - 2s 3us/step - loss: 0.3036 - acc: 0.8721 - val_loss: 0.3073 - val_acc: 0.8713
#
# Epoch 00030: val_acc improved from 0.87069 to 0.87133, saving model to weights_T1qqqq2016_unweighted_btagDeepCSV_excluded_V02.best.hdf5
# Epoch 31/100
# 563759/563759 [==============================] - 2s 3us/step - loss: 0.3037 - acc: 0.8719 - val_loss: 0.3058 - val_acc: 0.8704
#
# Epoch 00031: val_acc did not improve from 0.87133
# Epoch 32/100
# 563759/563759 [==============================] - 2s 3us/step - loss: 0.3031 - acc: 0.8723 - val_loss: 0.3066 - val_acc: 0.8695
#
# Epoch 00032: val_acc did not improve from 0.87133
# Epoch 33/100
# 563759/563759 [==============================] - 2s 3us/step - loss: 0.3037 - acc: 0.8721 - val_loss: 0.3088 - val_acc: 0.8709
#
# Epoch 00033: val_acc did not improve from 0.87133
# Epoch 34/100
# 563759/563759 [==============================] - 2s 3us/step - loss: 0.3028 - acc: 0.8722 - val_loss: 0.3061 - val_acc: 0.8705
#
# Epoch 00034: val_acc did not improve from 0.87133
# Epoch 35/100
# 563759/563759 [==============================] - 2s 3us/step - loss: 0.3027 - acc: 0.8723 - val_loss: 0.3061 - val_acc: 0.8715
#
# Epoch 00035: val_acc improved from 0.87133 to 0.87153, saving model to weights_T1qqqq2016_unweighted_btagDeepCSV_excluded_V02.best.hdf5
# Epoch 36/100
# 563759/563759 [==============================] - 2s 3us/step - loss: 0.3027 - acc: 0.8724 - val_loss: 0.3052 - val_acc: 0.8708
#
# Epoch 00036: val_acc did not improve from 0.87153
# Epoch 37/100
# 563759/563759 [==============================] - 2s 3us/step - loss: 0.3024 - acc: 0.8724 - val_loss: 0.3050 - val_acc: 0.8707
#
# Epoch 00037: val_acc did not improve from 0.87153
# Epoch 38/100
# 563759/563759 [==============================] - 2s 3us/step - loss: 0.3024 - acc: 0.8725 - val_loss: 0.3133 - val_acc: 0.8706
#
# Epoch 00038: val_acc did not improve from 0.87153
# Epoch 39/100
# 563759/563759 [==============================] - 2s 3us/step - loss: 0.3024 - acc: 0.8726 - val_loss: 0.3087 - val_acc: 0.8691
#
# Epoch 00039: val_acc did not improve from 0.87153
# Epoch 40/100
# 563759/563759 [==============================] - 2s 3us/step - loss: 0.3017 - acc: 0.8729 - val_loss: 0.3057 - val_acc: 0.8709
#
# Epoch 00040: val_acc did not improve from 0.87153
# Epoch 41/100
# 563759/563759 [==============================] - 2s 3us/step - loss: 0.3012 - acc: 0.8730 - val_loss: 0.3067 - val_acc: 0.8703
#
# Epoch 00041: val_acc did not improve from 0.87153
# Epoch 42/100
# 563759/563759 [==============================] - 2s 3us/step - loss: 0.3016 - acc: 0.8728 - val_loss: 0.3045 - val_acc: 0.8714
#
# Epoch 00042: val_acc did not improve from 0.87153
# Epoch 43/100
# 563759/563759 [==============================] - 2s 3us/step - loss: 0.3015 - acc: 0.8729 - val_loss: 0.3051 - val_acc: 0.8700
#
# Epoch 00043: val_acc did not improve from 0.87153
# Epoch 44/100
# 563759/563759 [==============================] - 2s 3us/step - loss: 0.3015 - acc: 0.8728 - val_loss: 0.3058 - val_acc: 0.8710
#
# Epoch 00044: val_acc did not improve from 0.87153
# Epoch 45/100
# 563759/563759 [==============================] - 2s 3us/step - loss: 0.3011 - acc: 0.8730 - val_loss: 0.3041 - val_acc: 0.8713
#
# Epoch 00045: val_acc did not improve from 0.87153
# Epoch 46/100
# 563759/563759 [==============================] - 2s 3us/step - loss: 0.3016 - acc: 0.8726 - val_loss: 0.3115 - val_acc: 0.8703
#
# Epoch 00046: val_acc did not improve from 0.87153
# Epoch 47/100
# 563759/563759 [==============================] - 2s 3us/step - loss: 0.3013 - acc: 0.8729 - val_loss: 0.3052 - val_acc: 0.8699
#
# Epoch 00047: val_acc did not improve from 0.87153
# Epoch 48/100
# 563759/563759 [==============================] - 2s 3us/step - loss: 0.3007 - acc: 0.8732 - val_loss: 0.3043 - val_acc: 0.8715
#
# Epoch 00048: val_acc did not improve from 0.87153
# Epoch 49/100
# 563759/563759 [==============================] - 2s 3us/step - loss: 0.3017 - acc: 0.8726 - val_loss: 0.3043 - val_acc: 0.8706
#
# Epoch 00049: val_acc did not improve from 0.87153
# Epoch 50/100
# 563759/563759 [==============================] - 2s 3us/step - loss: 0.3009 - acc: 0.8732 - val_loss: 0.3039 - val_acc: 0.8712
#
# Epoch 00050: val_acc did not improve from 0.87153
# Epoch 51/100
# 563759/563759 [==============================] - 2s 3us/step - loss: 0.3002 - acc: 0.8731 - val_loss: 0.3049 - val_acc: 0.8709
#
# Epoch 00051: val_acc did not improve from 0.87153
# Epoch 52/100
# 563759/563759 [==============================] - 2s 3us/step - loss: 0.3003 - acc: 0.8733 - val_loss: 0.3033 - val_acc: 0.8710
#
# Epoch 00052: val_acc did not improve from 0.87153
# Epoch 53/100
# 563759/563759 [==============================] - 2s 3us/step - loss: 0.3011 - acc: 0.8729 - val_loss: 0.3041 - val_acc: 0.8708
#
# Epoch 00053: val_acc did not improve from 0.87153
# Epoch 54/100
# 563759/563759 [==============================] - 2s 3us/step - loss: 0.2999 - acc: 0.8733 - val_loss: 0.3083 - val_acc: 0.8700
#
# Epoch 00054: val_acc did not improve from 0.87153
# Epoch 55/100
# 563759/563759 [==============================] - 2s 3us/step - loss: 0.3004 - acc: 0.8732 - val_loss: 0.3035 - val_acc: 0.8710
#
# Epoch 00055: val_acc did not improve from 0.87153
# Epoch 56/100
# 563759/563759 [==============================] - 2s 3us/step - loss: 0.2996 - acc: 0.8735 - val_loss: 0.3058 - val_acc: 0.8704
#
# Epoch 00056: val_acc did not improve from 0.87153
# Epoch 57/100
# 563759/563759 [==============================] - 2s 3us/step - loss: 0.2999 - acc: 0.8733 - val_loss: 0.3042 - val_acc: 0.8710
#
# Epoch 00057: val_acc did not improve from 0.87153
# Epoch 58/100
# 563759/563759 [==============================] - 2s 3us/step - loss: 0.2996 - acc: 0.8736 - val_loss: 0.3047 - val_acc: 0.8710
#
# Epoch 00058: val_acc did not improve from 0.87153
# Epoch 59/100
# 563759/563759 [==============================] - 2s 3us/step - loss: 0.2993 - acc: 0.8735 - val_loss: 0.3029 - val_acc: 0.8708
#
# Epoch 00059: val_acc did not improve from 0.87153
# Epoch 60/100
# 563759/563759 [==============================] - 2s 3us/step - loss: 0.2993 - acc: 0.8734 - val_loss: 0.3033 - val_acc: 0.8710
#
# Epoch 00060: val_acc did not improve from 0.87153
# Epoch 61/100
# 563759/563759 [==============================] - 2s 3us/step - loss: 0.2992 - acc: 0.8738 - val_loss: 0.3032 - val_acc: 0.8718
#
# Epoch 00061: val_acc improved from 0.87153 to 0.87176, saving model to weights_T1qqqq2016_unweighted_btagDeepCSV_excluded_V02.best.hdf5
# Epoch 62/100
# 563759/563759 [==============================] - 2s 3us/step - loss: 0.2991 - acc: 0.8737 - val_loss: 0.3039 - val_acc: 0.8705
#
# Epoch 00062: val_acc did not improve from 0.87176
# Epoch 63/100
# 563759/563759 [==============================] - 2s 3us/step - loss: 0.2987 - acc: 0.8738 - val_loss: 0.3047 - val_acc: 0.8713
#
# Epoch 00063: val_acc did not improve from 0.87176
# Epoch 64/100
# 563759/563759 [==============================] - 2s 3us/step - loss: 0.2992 - acc: 0.8738 - val_loss: 0.3032 - val_acc: 0.8718
#
# Epoch 00064: val_acc improved from 0.87176 to 0.87183, saving model to weights_T1qqqq2016_unweighted_btagDeepCSV_excluded_V02.best.hdf5
# Epoch 65/100
# 563759/563759 [==============================] - 2s 3us/step - loss: 0.2990 - acc: 0.8735 - val_loss: 0.3043 - val_acc: 0.8718
#
# Epoch 00065: val_acc did not improve from 0.87183
# Epoch 66/100
# 563759/563759 [==============================] - 2s 3us/step - loss: 0.2989 - acc: 0.8737 - val_loss: 0.3029 - val_acc: 0.8714
#
# Epoch 00066: val_acc did not improve from 0.87183
# Epoch 67/100
# 563759/563759 [==============================] - 2s 3us/step - loss: 0.2993 - acc: 0.8736 - val_loss: 0.3041 - val_acc: 0.8703
#
# Epoch 00067: val_acc did not improve from 0.87183
# Epoch 68/100
# 563759/563759 [==============================] - 2s 3us/step - loss: 0.2989 - acc: 0.8737 - val_loss: 0.3038 - val_acc: 0.8707
#
# Epoch 00068: val_acc did not improve from 0.87183
# Epoch 69/100
# 563759/563759 [==============================] - 2s 3us/step - loss: 0.2988 - acc: 0.8738 - val_loss: 0.3030 - val_acc: 0.8718
#
# Epoch 00069: val_acc improved from 0.87183 to 0.87183, saving model to weights_T1qqqq2016_unweighted_btagDeepCSV_excluded_V02.best.hdf5
# Epoch 70/100
# 563759/563759 [==============================] - 2s 3us/step - loss: 0.2985 - acc: 0.8738 - val_loss: 0.3032 - val_acc: 0.8715
#
# Epoch 00070: val_acc did not improve from 0.87183
# Epoch 71/100
# 563759/563759 [==============================] - 2s 3us/step - loss: 0.2984 - acc: 0.8740 - val_loss: 0.3028 - val_acc: 0.8722
#
# Epoch 00071: val_acc improved from 0.87183 to 0.87224, saving model to weights_T1qqqq2016_unweighted_btagDeepCSV_excluded_V02.best.hdf5
# Epoch 72/100
# 563759/563759 [==============================] - 2s 3us/step - loss: 0.2983 - acc: 0.8738 - val_loss: 0.3037 - val_acc: 0.8718
#
# Epoch 00072: val_acc did not improve from 0.87224
# Epoch 73/100
# 563759/563759 [==============================] - 2s 3us/step - loss: 0.2985 - acc: 0.8738 - val_loss: 0.3043 - val_acc: 0.8709
#
# Epoch 00073: val_acc did not improve from 0.87224
# Epoch 74/100
# 563759/563759 [==============================] - 2s 3us/step - loss: 0.2981 - acc: 0.8741 - val_loss: 0.3024 - val_acc: 0.8722
#
# Epoch 00074: val_acc improved from 0.87224 to 0.87224, saving model to weights_T1qqqq2016_unweighted_btagDeepCSV_excluded_V02.best.hdf5
# Epoch 75/100
# 563759/563759 [==============================] - 2s 3us/step - loss: 0.2979 - acc: 0.8741 - val_loss: 0.3025 - val_acc: 0.8719
#
# Epoch 00075: val_acc did not improve from 0.87224
# Epoch 76/100
# 563759/563759 [==============================] - 2s 3us/step - loss: 0.2983 - acc: 0.8741 - val_loss: 0.3083 - val_acc: 0.8695
#
# Epoch 00076: val_acc did not improve from 0.87224
# Epoch 77/100
# 563759/563759 [==============================] - 2s 3us/step - loss: 0.2977 - acc: 0.8738 - val_loss: 0.3024 - val_acc: 0.8720
#
# Epoch 00077: val_acc did not improve from 0.87224
# Epoch 78/100
# 563759/563759 [==============================] - 2s 3us/step - loss: 0.2975 - acc: 0.8742 - val_loss: 0.3056 - val_acc: 0.8700
#
# Epoch 00078: val_acc did not improve from 0.87224
# Epoch 79/100
# 563759/563759 [==============================] - 2s 3us/step - loss: 0.2980 - acc: 0.8740 - val_loss: 0.3021 - val_acc: 0.8721
#
# Epoch 00079: val_acc did not improve from 0.87224
# Epoch 80/100
# 563759/563759 [==============================] - 2s 3us/step - loss: 0.2970 - acc: 0.8744 - val_loss: 0.3019 - val_acc: 0.8722
#
# Epoch 00080: val_acc did not improve from 0.87224
# Epoch 81/100
# 563759/563759 [==============================] - 2s 3us/step - loss: 0.2972 - acc: 0.8744 - val_loss: 0.3031 - val_acc: 0.8718
#
# Epoch 00081: val_acc did not improve from 0.87224
# Epoch 82/100
# 563759/563759 [==============================] - 2s 3us/step - loss: 0.2975 - acc: 0.8744 - val_loss: 0.3050 - val_acc: 0.8711
#
# Epoch 00082: val_acc did not improve from 0.87224
# Epoch 83/100
# 563759/563759 [==============================] - 2s 3us/step - loss: 0.2977 - acc: 0.8743 - val_loss: 0.3034 - val_acc: 0.8717
#
# Epoch 00083: val_acc did not improve from 0.87224
# Epoch 84/100
# 563759/563759 [==============================] - 2s 3us/step - loss: 0.2966 - acc: 0.8746 - val_loss: 0.3022 - val_acc: 0.8719
#
# Epoch 00084: val_acc did not improve from 0.87224
# Epoch 85/100
# 563759/563759 [==============================] - 2s 3us/step - loss: 0.2962 - acc: 0.8746 - val_loss: 0.3048 - val_acc: 0.8709
#
# Epoch 00085: val_acc did not improve from 0.87224
# Epoch 86/100
# 563759/563759 [==============================] - 2s 3us/step - loss: 0.2964 - acc: 0.8746 - val_loss: 0.3023 - val_acc: 0.8734
#
# Epoch 00086: val_acc improved from 0.87224 to 0.87345, saving model to weights_T1qqqq2016_unweighted_btagDeepCSV_excluded_V02.best.hdf5
# Epoch 87/100
# 563759/563759 [==============================] - 2s 3us/step - loss: 0.2968 - acc: 0.8746 - val_loss: 0.3018 - val_acc: 0.8716
#
# Epoch 00087: val_acc did not improve from 0.87345
# Epoch 88/100
# 563759/563759 [==============================] - 2s 3us/step - loss: 0.2961 - acc: 0.8748 - val_loss: 0.3019 - val_acc: 0.8720
#
# Epoch 00088: val_acc did not improve from 0.87345
# Epoch 89/100
# 563759/563759 [==============================] - 2s 3us/step - loss: 0.2959 - acc: 0.8751 - val_loss: 0.3014 - val_acc: 0.8728
#
# Epoch 00089: val_acc did not improve from 0.87345
# Epoch 90/100
# 563759/563759 [==============================] - 2s 3us/step - loss: 0.2952 - acc: 0.8752 - val_loss: 0.3012 - val_acc: 0.8729
#
# Epoch 00090: val_acc did not improve from 0.87345
# Epoch 91/100
# 563759/563759 [==============================] - 2s 3us/step - loss: 0.2954 - acc: 0.8751 - val_loss: 0.3011 - val_acc: 0.8723
#
# Epoch 00091: val_acc did not improve from 0.87345
# Epoch 92/100
# 563759/563759 [==============================] - 2s 3us/step - loss: 0.2952 - acc: 0.8752 - val_loss: 0.3010 - val_acc: 0.8727
#
# Epoch 00092: val_acc did not improve from 0.87345
# Epoch 93/100
# 563759/563759 [==============================] - 2s 3us/step - loss: 0.2957 - acc: 0.8749 - val_loss: 0.3007 - val_acc: 0.8728
#
# Epoch 00093: val_acc did not improve from 0.87345
# Epoch 94/100
# 563759/563759 [==============================] - 2s 3us/step - loss: 0.2950 - acc: 0.8753 - val_loss: 0.3037 - val_acc: 0.8719
#
# Epoch 00094: val_acc did not improve from 0.87345
# Epoch 95/100
# 563759/563759 [==============================] - 2s 3us/step - loss: 0.2956 - acc: 0.8750 - val_loss: 0.3011 - val_acc: 0.8722
#
# Epoch 00095: val_acc did not improve from 0.87345
# Epoch 96/100
# 563759/563759 [==============================] - 2s 3us/step - loss: 0.2948 - acc: 0.8755 - val_loss: 0.3004 - val_acc: 0.8734
#
# Epoch 00096: val_acc did not improve from 0.87345
# Epoch 97/100
# 563759/563759 [==============================] - 2s 3us/step - loss: 0.2943 - acc: 0.8755 - val_loss: 0.3015 - val_acc: 0.8721
#
# Epoch 00097: val_acc did not improve from 0.87345
# Epoch 98/100
# 563759/563759 [==============================] - 2s 3us/step - loss: 0.2950 - acc: 0.8754 - val_loss: 0.3010 - val_acc: 0.8727
#
# Epoch 00098: val_acc did not improve from 0.87345
# Epoch 99/100
# 563759/563759 [==============================] - 2s 3us/step - loss: 0.2937 - acc: 0.8757 - val_loss: 0.3010 - val_acc: 0.8725
#
# Epoch 00099: val_acc did not improve from 0.87345
# Epoch 100/100
# 563759/563759 [==============================] - 2s 3us/step - loss: 0.2936 - acc: 0.8760 - val_loss: 0.3000 - val_acc: 0.8733
#
# Epoch 00100: val_acc did not improve from 0.87345

# %%
model1 = Sequential()
model1.add(Dense(128, input_shape=(X[features_train].shape[1],), kernel_initializer='normal', activation='relu'))
model1.add(Dense(64, kernel_initializer='normal', activation='sigmoid'))
model1.add(Dense(64, kernel_initializer='normal', activation='sigmoid'))
model1.add(Dense(1, kernel_initializer='normal', activation='sigmoid'))
model1.compile(optimizer="adam", loss='binary_crossentropy',metrics=['accuracy'])
#model1.load_weights("weights_T1qqqq2016_unweighted.best.hdf5")
model1.load_weights("weights_T1qqqq2016_unweighted_btagDeepCSV_excluded_V02.best.hdf5")

# %%
#model1.save("model_T1qqqq2016_unweighted.h5")
model1.save("model_T1qqqq2016_unweighted_btagDeepCSV_excluded_V02.h5")

# %%
def plot_history(histories, key_loss='loss',key_metric='acc'):
    fig=plt.figure(figsize=(16,10))
    ax1 = fig.add_subplot(211)
    ax2 = fig.add_subplot(212)
    for name, history in histories:
        val_loss = ax1.plot(history.epoch, history.history['val_'+key_loss],
                   '--', label=name.title()+' Val'+' - binary cross entropy')
        ax1.plot(history.epoch, history.history[key_loss], color=val_loss[0].get_color(),
             label=name.title()+' Train'+' - binary cross entropy')
        val_metric=ax2.plot(history.epoch, history.history['val_'+key_metric],
                   '--', label=name.title()+' Val'+' - accuracy')
        ax2.plot(history.epoch, history.history[key_metric], color=val_metric[0].get_color(),
             label=name.title()+' Train'+' - accuracy')
    ax1.set_xlabel('Epochs',fontsize=18)
    ax1.set_ylabel('Loss funtion',fontsize=18)
    ax1.legend(loc='best',prop={'size': 12})
    ax1.set_title("classification learning curve - loss funcion",fontsize=20)
    ax1.set_xlim([0,max(history.epoch)])
    ax2.set_xlabel('Epochs',fontsize=18)
    ax2.set_ylabel('Metric',fontsize=18)
    ax2.legend(loc='best',prop={'size': 12})
    ax2.set_title("classification learning curve - metric",fontsize=20)
    ax2.set_xlim([0,max(history.epoch)])
    return fig

# %%
fig=plot_history([('signal - background classification',model_history)])
#fig.savefig('T1qqqq_unweighted_learningcurve_V02.pdf')
#fig.savefig('T1qqqq_unweighted_learningcurve_V02.png')
fig.savefig('T1qqqq_unweighted_learningcurve_btagDeepCSVexcluded_V02.pdf')
fig.savefig('T1qqqq_unweighted_learningcurve_btagDeepCSVexcluded_V02.png')

# %%
results = model1.predict(X_val[features_train[:]], batch_size=10000)

# %%
from sklearn.metrics import roc_auc_score
auc = roc_auc_score(y_val, results)
#auc = roc_auc_score(y_test, results)
print("area under ROC curve: ", auc)
# Out:
# area under ROC curve:  0.8978615156395956

# %%
sigtest_score= model1.predict(datasig_T1qqqq_2016_test[features_train[:]], batch_size=10000)
bkgtest_score= model1.predict(databkg_2016_test[features_train[:]],batch_size=10000)

# %%
databkg_2016_test[b'MLscore']=bkgtest_score
datasig_T1qqqq_2016_test[b'MLscore']=sigtest_score

# %%
fig3 = plt.figure(figsize=(20,10))
ax3 = fig3.add_subplot(111)
bkgscore=[databkg_2016_test[databkg_2016_test[b'bkgtype']==0][b'MLscore'], \
          databkg_2016_test[(databkg_2016_test[b'bkgtype']==1)|(databkg_2016_test[b'bkgtype']==2)][b'MLscore'], \
         databkg_2016_test[databkg_2016_test[b'bkgtype']==3][b'MLscore'],
         databkg_2016_test[databkg_2016_test[b'bkgtype']==4][b'MLscore']]
bkgweight=[databkg_2016_test[databkg_2016_test[b'bkgtype']==0][b'evt_scale1fb'], \
          databkg_2016_test[(databkg_2016_test[b'bkgtype']==1)|(databkg_2016_test[b'bkgtype']==2)][b'evt_scale1fb'], \
         databkg_2016_test[databkg_2016_test[b'bkgtype']==3][b'evt_scale1fb'],
         databkg_2016_test[databkg_2016_test[b'bkgtype']==4][b'evt_scale1fb']]
bkgname=['qcd','top','wjets','zinv']
ax3.hist(bkgscore,bins=np.arange(0,1.025,0.025),stacked=True,alpha=0.5,label=bkgname,density=True,weights=bkgweight)
ax3.hist(datasig_T1qqqq_2016_test[b'MLscore'],bins=np.arange(0,1.025,0.025),alpha=1,label='score of test: signal',density=True,histtype='step',linewidth=2)
ax3.legend(loc='upper left',prop={'size': 12})
ax3.set_title("T1qqqq 2016 score distribution of signal and background for testing set",fontsize=20)
ax3.set_xlabel('Score',fontsize=18)
ax3.set_ylabel('fraction',fontsize=18)
#fig3.savefig('T1qqqq_2016_scoredistribution_V02.pdf')
#fig3.savefig('T1qqqq_2016_scoredistribution_V02.png')
#fig3.savefig('T1bbbb_2016_scoredistribution.pdf')
#fig3.savefig('T1bbbb_2016_scoredistribution.png')
#fig3.savefig('T1bbbb_2016_scoredistribution_btagDeepCSV_excluded.pdf')
#fig3.savefig('T1bbbb_2016_scoredistribution_btagDeepCSV_excluded.png')
fig3.savefig('T1qqqq_2016_scoredistribution_btagDeepCSV_excluded_V02.pdf')
fig3.savefig('T1qqqq_2016_scoredistribution_btagDeepCSV_excluded_V02.png')

# %%
fig6 = plt.figure(figsize=(20,10))
ax6 = fig6.add_subplot(111)
ax6.hist(databkg_2016_test[b'MLscore'],bins=np.arange(0,1.05,0.05),alpha=0.5,label='score of test: background',density=True,weights=databkg_2016_test[b'evt_scale1fb'])
ax6.hist(datasig_T1qqqq_2016_test[b'MLscore'],bins=np.arange(0,1.05,0.05),alpha=0.5,label='score of test: signal',density=True)
ax6.legend(loc='best',prop={'size': 12})
ax6.set_title("score distribution of signal and background for testing set",fontsize=20)
ax6.set_xlabel('Score',fontsize=18)
ax6.set_ylabel('fraction',fontsize=18)

# %%
fig1 = plt.figure(figsize=(20,10))
ax0 = fig1.add_subplot(111)
bins=np.histogram(datasig_T1qqqq_2016_test[b'mt2'],bins=30)[1]
labels=['mt2 of signal T1qqqq before cut','mt2 of signal T1qqqq after cut']
ax0.hist(datasig_T1qqqq_2016_test[b'mt2'],
             bins=bins,density=True,alpha=0.5,color='orange',
             label=labels[0])
ax0.hist(datasig_T1qqqq_2016_test[datasig_T1qqqq_2016_test[b'MLscore']>0.5][b'mt2'],
             bins=bins,density=True,color='b',histtype='step',
             label=labels[1])
ax0.legend(loc='best',prop={'size': 12})
#ax0.set_xscale('log')
ax0.set_yscale('log')
ax0.set_xlabel('mt2',fontsize=18)
ax0.set_ylabel('fraction',fontsize=18)
ax0.set_title('comparison of T1qqqq signal before and after cut',size=20)
fig1.show()

# %%
fig2 = plt.figure(figsize=(20,10))
ax2 = fig2.add_subplot(111)
bins=np.histogram(databkg_2016_test[b'mt2'],bins=30)[1]
labels=['mt2 of accumulated background before cut','mt2 of accululated background after cut']
ax2.hist(databkg_2016_test[b'mt2'],
             bins=bins,density=True,alpha=0.5,color='orange',
         weights=databkg_2016_test[b'evt_scale1fb'],
             label=labels[0])
ax2.hist(databkg_2016_test[databkg_2016_test[b'MLscore']>0.5][b'mt2'],
             bins=bins,density=True,color='b',histtype='step',
         weights=databkg_2016_test[databkg_2016_test[b'MLscore']>0.5][b'evt_scale1fb'],
             label=labels[1])
ax2.legend(loc='best',prop={'size': 12})
ax2.set_yscale('log')
ax2.set_xlabel('mt2',fontsize=18)
ax2.set_ylabel('fraction',fontsize=18)
ax2.set_title('comparison of total background before and after cut',size=20)
fig2.show()

# %%
fig3 = plt.figure(figsize=(20,10))
ax3 = fig3.add_subplot(111)
bins=np.histogram(databkg_2016_test[databkg_2016_test[b'bkgtype']==4][b'mt2'],bins=30)[1]
labels=['mt2 of zinv background before cut','mt2 of zinv background after cut']
ax3.hist(databkg_2016_test[databkg_2016_test[b'bkgtype']==4][b'mt2'],
             bins=bins,density=True,alpha=0.5,color='orange',
         weights=databkg_2016_test[databkg_2016_test[b'bkgtype']==4][b'evt_scale1fb'],
             label=labels[0])
ax3.hist(databkg_2016_test[(databkg_2016_test[b'MLscore']>0.5)&(databkg_2016_test[b'bkgtype']==4)][b'mt2'],
             bins=bins,density=True,color='b',histtype='step',
         weights=databkg_2016_test[(databkg_2016_test[b'MLscore']>0.5)&(databkg_2016_test[b'bkgtype']==4)][b'evt_scale1fb'],
             label=labels[1])
ax3.legend(loc='best',prop={'size': 12})
ax3.set_yscale('log')
ax3.set_xlabel('mt2',fontsize=18)
ax3.set_ylabel('fraction',fontsize=18)
ax3.set_title('comparison of zinv background before and after cut',size=20)
fig3.show()

# %%
fig4 = plt.figure(figsize=(20,10))
ax4 = fig4.add_subplot(111)
bins=np.histogram(databkg_2016_test[databkg_2016_test[b'bkgtype']==3][b'mt2'],bins=30)[1]
logbins = np.logspace(np.log10(bins[0]),np.log10(bins[-1]),len(bins))
labels=['mt2 of wjets background before cut','mt2 of wjets background after cut']
ax4.hist(databkg_2016_test[databkg_2016_test[b'bkgtype']==3][b'mt2'],
             bins=logbins,density=True,alpha=0.5,color='orange',
         weights=databkg_2016_test[databkg_2016_test[b'bkgtype']==3][b'evt_scale1fb'],
             label=labels[0])
ax4.hist(databkg_2016_test[(databkg_2016_test[b'MLscore']>0.5)&(databkg_2016_test[b'bkgtype']==3)][b'mt2'],
             bins=logbins,density=True,color='b',histtype='step',
         weights=databkg_2016_test[(databkg_2016_test[b'MLscore']>0.5)&(databkg_2016_test[b'bkgtype']==3)][b'evt_scale1fb'],
             label=labels[1])
ax4.legend(loc='best',prop={'size': 12})
ax4.set_xscale('log')
ax4.set_xlabel('mt2',fontsize=18)
ax4.set_ylabel('fraction',fontsize=18)
ax4.set_title('comparison of wjets background before and after cut',size=20)
fig4.show()

# %%
fig5 = plt.figure(figsize=(20,10))
ax5 = fig5.add_subplot(111)
bins=np.histogram(databkg_2016_test[databkg_2016_test[b'bkgtype']==0][b'mt2'],bins=30)[1]
labels=['mt2 of singletop background before cut','mt2 of singletop background after cut']
ax5.hist(databkg_2016_test[databkg_2016_test[b'bkgtype']==0][b'mt2'],
             bins=bins,density=True,alpha=0.5,color='orange',
         weights=databkg_2016_test[databkg_2016_test[b'bkgtype']==0][b'evt_scale1fb'],
             label=labels[0])
ax5.hist(databkg_2016_test[(databkg_2016_test[b'MLscore']>0.5)&(databkg_2016_test[b'bkgtype']==0)][b'mt2'],
             bins=bins,density=True,color='b',histtype='step',
         weights=databkg_2016_test[(databkg_2016_test[b'MLscore']>0.5)&(databkg_2016_test[b'bkgtype']==0)][b'evt_scale1fb'],
             label=labels[1])
ax5.legend(loc='best',prop={'size': 12})
ax5.set_yscale('log')
ax5.set_xlabel('mt2',fontsize=18)
ax5.set_ylabel('fraction',fontsize=18)
ax5.set_title('comparison of qcd background before and after cut',size=20)
fig5.show()

# %%
fig7 = plt.figure(figsize=(20,10))
ax7 = fig7.add_subplot(111)
bins=np.histogram(databkg_2016_test[(databkg_2016_test[b'bkgtype']==1)|(databkg_2016_test[b'bkgtype']==2)][b'mt2'],bins=30)[1]
labels=['mt2 of singletop background before cut','mt2 of singletop background after cut']
ax7.hist(databkg_2016_test[(databkg_2016_test[b'bkgtype']==1)|(databkg_2016_test[b'bkgtype']==2)][b'mt2'],
             bins=bins,density=True,alpha=0.5,color='orange',
         weights=databkg_2016_test[(databkg_2016_test[b'bkgtype']==1)|(databkg_2016_test[b'bkgtype']==2)][b'evt_scale1fb'],
             label=labels[0])
ax7.hist(databkg_2016_test[(databkg_2016_test[b'MLscore']>0.5)&((databkg_2016_test[b'bkgtype']==1)|(databkg_2016_test[b'bkgtype']==2))][b'mt2'],
             bins=bins,density=True,color='b',histtype='step',
         weights=databkg_2016_test[(databkg_2016_test[b'MLscore']>0.5)&((databkg_2016_test[b'bkgtype']==1)|(databkg_2016_test[b'bkgtype']==2))][b'evt_scale1fb'],
             label=labels[1])
ax7.legend(loc='best',prop={'size': 12})
ax7.set_yscale('log')
ax7.set_xlabel('mt2',fontsize=18)
ax7.set_ylabel('fraction',fontsize=18)
ax7.set_title('comparison of top background before and after cut',size=20)
fig7.show()
